# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
#read csv file
df = pd.read_csv("FDM1.csv")

# %%
df.head()
# Out:
#     Make       Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA         ILX       COMPACT             2.0        4.0          AS5
# 1  ACURA         ILX       COMPACT            15.0        4.0          AS5
# 2  ACURA         ILX       COMPACT             2.4        4.0           M6
# 3  ACURA  ILX HYBRID       COMPACT             1.5        4.0          AV7
# 4  ACURA     MDX 4WD   SUV - SMALL             3.5        6.0          AS6
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                               9.9
# 2         Z                              11.2
# 3         Z                               6.0
# 4         Z                              12.7
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              6.7                               8.5
# 2                              7.7                               9.6
# 3                              5.8                               5.9
# 4                              9.1                              11.1
#
#    Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 0                         33.0                196.0
# 1                         33.0                196.0
# 2                         29.0                221.0
# 3                         48.0                136.0
# 4                         25.0                255.0

# %%
#checking wheater there is null value
df.isna().sum()
# Out:
# Make                                 0
# Model                                1
# Vehicle Class                        3
# Engine Size(L)                       3
# Cylinders                            2
# Transmission                         8
# Fuel Type                            4
# Fuel Consumption City (L/100 km)    10
# Fuel Consumption Hwy (L/100 km)      9
# Fuel Consumption Comb (L/100 km)     9
# Fuel Consumption Comb (mpg)          5
# CO2 Emissions(g/km)                 10
# dtype: int64

# %%
df[df[["Model"]].isnull().any(axis = 1)]
# Out:
#     Make Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 9  ACURA   NaN      MID-SIZE             3.5        6.0          AS7
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 9         Z                              12.6
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 9                              9.2                              10.1
#
#    Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 9                         25.0                259.0

# %%
df[(df["Make"] == "ACURA") & (df["Cylinders"] == 6.0) ]
# Out:
#      Make                              Model Vehicle Class  Engine Size(L)  \
# 4   ACURA                            MDX 4WD   SUV - SMALL             3.5
# 5   ACURA                            RDX AWD   SUV - SMALL             3.5
# 6   ACURA                                RLX      MID-SIZE             3.5
# 7   ACURA                                 TL      MID-SIZE             3.5
# 8   ACURA                             TL AWD      MID-SIZE             3.7
# 9   ACURA                                NaN      MID-SIZE             3.5
# 10  ACURA                             TL AWD      MID-SIZE             3.7
# 11  ACURA                             TL AWD      MID-SIZE             3.5
# 14  ACURA                                TSX       COMPACT             3.5
# 19  ACURA                         MDX SH-AWD   SUV - SMALL             3.5
# 20  ACURA                            RDX AWD   SUV - SMALL             3.5
# 24  ACURA                                RLX      MID-SIZE             3.5
# 25  ACURA                         RLX HYBRID      MID-SIZE             3.5
# 27  ACURA                                TLX       COMPACT             3.5
# 28  ACURA                         TLX SH-AWD       COMPACT             3.5
# 30  ACURA                         MDX SH-AWD   SUV - SMALL             3.5
# 31  ACURA                   MDX SH-AWD ELITE   SUV - SMALL             3.5
# 32  ACURA                            RDX AWD   SUV - SMALL             3.5
# 33  ACURA                                RLX      MID-SIZE             3.5
# 34  ACURA                         RLX HYBRID      MID-SIZE             3.5
# 36  ACURA                         TLX SH-AWD       COMPACT             3.5
# 38  ACURA                         MDX SH-AWD   SUV - SMALL             3.5
# 39  ACURA                   MDX SH-AWD ELITE   SUV - SMALL             3.5
# 40  ACURA                     MDX HYBRID AWD   SUV - SMALL             3.0
# 41  ACURA                                NSX    TWO-SEATER             3.5
# 42  ACURA                            RDX AWD   SUV - SMALL             3.5
# 43  ACURA                         RLX HYBRID      MID-SIZE             3.5
# 45  ACURA                         TLX SH-AWD       COMPACT             3.5
# 47  ACURA                         MDX SH-AWD   SUV - SMALL             3.5
# 48  ACURA                   MDX SH-AWD ELITE   SUV - SMALL             3.5
# 49  ACURA                     MDX HYBRID AWD   SUV - SMALL             3.0
# 50  ACURA                                NSX    TWO-SEATER             3.5
# 51  ACURA                            RDX AWD   SUV - SMALL             3.5
# 52  ACURA                         RLX HYBRID      MID-SIZE             3.5
# 55  ACURA                         TLX SH-AWD           NaN             3.5
# 56  ACURA                         TLX SH-AWD       COMPACT            -5.6
# 57  ACURA                  TLX SH-AWD A-SPEC       COMPACT             3.5
# 59  ACURA                         MDX SH-AWD   SUV - SMALL             3.5
# 60  ACURA                  MDX SH-AWD A-SPEC   SUV - SMALL             3.5
# 61  ACURA                     MDX Hybrid AWD   SUV - SMALL             3.0
# 62  ACURA                                NSX    TWO-SEATER             3.5
# 65  ACURA                         RLX Hybrid      MID-SIZE             3.5
# 68  ACURA                         TLX SH-AWD       COMPACT             3.5
# 69  ACURA                  TLX SH-AWD A-SPEC       COMPACT             3.5
# 71  ACURA                         MDX SH-AWD   SUV - SMALL             3.5
# 72  ACURA                  MDX SH-AWD A-SPEC   SUV - SMALL             3.5
# 73  ACURA                     MDX Hybrid AWD   SUV - SMALL             3.0
# 76  ACURA                         RLX Hybrid      MID-SIZE             3.5
# 78  ACURA                         TLX SH-AWD       COMPACT             3.5
# 79  ACURA  TLX SH-AWD A-SPEC/Limited Edition       COMPACT             3.5
#
#     Cylinders Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 4         6.0          AS6         Z                              12.7
# 5         6.0          AS6         Z                              12.1
# 6         6.0          AS6         Z                              11.9
# 7         6.0          AS6         Z                              11.8
# 8         6.0          AS6         Z                              12.8
# 9         6.0          AS7         Z                              12.6
# 10        6.0           M6         Z                              13.4
# 11        6.0          AS6         Z                              11.9
# 14        6.0          AS5         Z                              12.1
# 19        6.0          AS6         Z                              12.7
# 20        6.0          AS6         Z                              12.1
# 24        6.0          AS6         Z                              11.9
# 25        6.0          AM7         Z                               8.0
# 27        6.0          AS9         Z                              11.2
# 28        6.0          AS9         Z                              11.2
# 30        6.0          AS9         Z                              12.7
# 31        6.0          AS9         Z                              12.2
# 32        6.0          AS6         Z                              12.4
# 33        6.0          AS6         Z                              11.9
# 34        6.0          AM7         Z                               8.0
# 36        6.0          AS9         Z                              11.2
# 38        6.0          AS9         Z                              12.6
# 39        6.0          AS9         Z                              12.2
# 40        6.0          AM7         Z                               9.1
# 41        6.0          AM9         Z                              11.1
# 42        6.0          AS6         Z                              12.4
# 43        6.0          AM7         Z                               8.2
# 45        6.0          AS9         Z                              11.2
# 47        6.0          AS9         Z                              12.6
# 48        6.0          AS9         Z                              12.2
# 49        6.0          AM7         Z                               9.1
# 50        6.0          AM9         Z                              11.1
# 51        6.0          AS6         Z                              12.4
# 52        6.0          AM7         Z                               8.4
# 55        6.0          AS9         Z                              11.4
# 56        6.0         AS10         Z                              10.0
# 57        6.0          AS9         Z                              12.0
# 59        6.0          AS9         Z                              12.2
# 60        6.0          AS9         Z                              12.2
# 61        6.0          AM7         Z                               9.1
# 62        6.0          AM9         Z                              11.1
# 65        6.0          AM7         Z                               8.4
# 68        6.0          AS9         Z                              11.4
# 69        6.0          AS9         Z                              12.0
# 71        6.0          AS9         Z                              12.3
# 72        6.0          AS9         Z                              12.2
# 73        6.0          AM7         Z                               9.1
# 76        6.0          AM7         Z                               8.4
# 78        6.0          AS9         Z                              11.4
# 79        6.0          AS9         Z                              12.0
#
#     Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 4                               9.1                             11.10
# 5                               8.7                             10.60
# 6                               7.7                             10.00
# 7                               8.1                             10.10
# 8                               9.0                             11.10
# 9                               9.2                             10.10
# 10                              9.5                             11.60
# 11                              8.0                              9.95
# 14                              8.3                             10.40
# 19                              9.1                             11.10
# 20                              8.7                             10.60
# 24                              7.7                             10.00
# 25                              7.5                              7.70
# 27                              6.9                              9.20
# 28                              7.5                              9.60
# 30                              9.1                             11.10
# 31                              9.1                             10.70
# 32                              8.6                             10.70
# 33                              7.7                             10.00
# 34                              7.5                              7.70
# 36                              7.5                              9.60
# 38                              9.0                             11.00
# 39                              9.0                             10.70
# 40                              9.0                              9.00
# 41                             10.8                             11.00
# 42                              8.7                             10.70
# 43                              7.8                              8.10
# 45                              7.5                              9.60
# 47                              9.0                             11.00
# 48                              9.0                             10.70
# 49                              9.0                              9.00
# 50                             10.8                             11.00
# 51                              8.7                             10.70
# 52                              8.2                              8.40
# 55                              7.7                              9.80
# 56                              1.2                              5.60
# 57                              8.2                             10.30
# 59                              9.0                             10.80
# 60                              9.5                             11.00
# 61                              9.0                              9.00
# 62                             10.8                             11.00
# 65                              8.2                              8.40
# 68                              7.7                              9.80
# 69                              8.2                             10.30
# 71                              9.2                             10.90
# 72                              9.5                             11.00
# 73                              9.0                              9.00
# 76                              8.2                              8.40
# 78                              7.7                              9.80
# 79                              8.2                             10.30
#
#     Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 4                          25.0                255.0
# 5                          27.0                244.0
# 6                          28.0                230.0
# 7                          28.0                232.0
# 8                          25.0                255.0
# 9                          25.0                259.0
# 10                         24.0                267.0
# 11                        -25.0                  NaN
# 14                         27.0                239.0
# 19                         25.0                255.0
# 20                         27.0                244.0
# 24                         28.0                230.0
# 25                         37.0                177.0
# 27                         31.0                212.0
# 28                         29.0                221.0
# 30                         25.0                254.0
# 31                         26.0                251.0
# 32                         26.0                249.0
# 33                         28.0                235.0
# 34                         37.0                180.0
# 36                         29.0                226.0
# 38                         26.0                259.0
# 39                         26.0                251.0
# 40                         31.0                210.0
# 41                         26.0                261.0
# 42                         26.0                250.0
# 43                         35.0                190.0
# 45                         29.0                226.0
# 47                         26.0                259.0
# 48                         26.0                251.0
# 49                         31.0                210.0
# 50                         26.0                261.0
# 51                         26.0                250.0
# 52                         34.0                196.0
# 55                         29.0                228.0
# 56                         30.0                228.0
# 57                         27.0                240.0
# 59                         26.0                252.0
# 60                         26.0                258.0
# 61                         31.0                210.0
# 62                         26.0                261.0
# 65                         34.0                196.0
# 68                         29.0                228.0
# 69                         27.0                240.0
# 71                         26.0                254.0
# 72                         26.0                258.0
# 73                         31.0                210.0
# 76                         34.0                196.0
# 78                         29.0                228.0
# 79                         27.0                240.0

# %%
#drop model null value
df = df.dropna(subset=["Model"])

# %%
df.isna().sum()
# Out:
# Make                                 0
# Model                                0
# Vehicle Class                        3
# Engine Size(L)                       3
# Cylinders                            2
# Transmission                         8
# Fuel Type                            4
# Fuel Consumption City (L/100 km)    10
# Fuel Consumption Hwy (L/100 km)      9
# Fuel Consumption Comb (L/100 km)     9
# Fuel Consumption Comb (mpg)          5
# CO2 Emissions(g/km)                 10
# dtype: int64

# %%
df[df[["CO2 Emissions(g/km)"]].isnull().any(axis = 1)]
# Out:
#              Make       Model Vehicle Class  Engine Size(L)  Cylinders  \
# 11          ACURA      TL AWD      MID-SIZE             3.5        6.0
# 15          ACURA         Tsx       COMPACT             2.7        4.0
# 22          ACURA     RDX AWD           NaN             NaN        8.0
# 148  AstON MARTIN    RAPIDE S    SUBCOMPACT             5.0       11.0
# 149  AstON MARTIN    RAPIDE S    SUBCOMPACT             4.0        8.0
# 150  AstON MARTIN    RAPIDE S    SUBCOMPACT             6.0       12.0
# 212          AUDI  A6 QUATTRO    SUBCOMPACT             4.2        4.0
# 213          AUDI  A6 QUATTRO      MID-SIZE             2.0        6.0
# 215          AUDI          s7      MID-SIZE             3.0        8.0
# 216          AUDI          s7    SUBCOMPACT             3.0        4.0
#
#     Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 11           AS6         Z                              11.9
# 15           NaN         Z                              15.5
# 22           NaN         Z                               NaN
# 148           A8         Z                              15.2
# 149          NaN       NaN                               NaN
# 150          NaN         Z                               NaN
# 212          AS8         Z                               NaN
# 213           A7         Z                               NaN
# 215           A7         Z                               NaN
# 216          AS8         Z                              14.2
#
#      Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 11                               8.0                              9.95
# 15                               NaN                               NaN
# 22                               NaN                              6.70
# 148                              NaN                               NaN
# 149                              NaN                               NaN
# 150                              NaN                             12.20
# 212                              9.5                               NaN
# 213                              8.1                               NaN
# 215                              NaN                             12.00
# 216                              NaN                               NaN
#
#      Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 11                         -25.0                  NaN
# 15                          25.0                  NaN
# 22                           NaN                  NaN
# 148                         15.0                  NaN
# 149                         19.0                  NaN
# 150                          NaN                  NaN
# 212                         11.0                  NaN
# 213                         15.0                  NaN
# 215                         23.0                  NaN
# 216                         21.0                  NaN

# %%
df = df.dropna(subset=["CO2 Emissions(g/km)"])

# %%
df[df[["Fuel Consumption Comb (L/100 km)"]].isnull().any(axis = 1)]
# Out:
#       Make       Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 21   ACURA         ILX       COMPACT             NaN        NaN          NaN
# 214   AUDI          s7    SUBCOMPACT             2.0       10.0          AS8
# 590    BMW  335i SEDAN       COMPACT            10.0        2.0          NaN
#
#     Fuel Type  Fuel Consumption City (L/100 km)  \
# 21        NaN                               NaN
# 214         Z                               NaN
# 590         Z                              11.5
#
#      Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 21                               5.8                               NaN
# 214                              8.8                               NaN
# 590                              8.0                               NaN
#
#      Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 21                          28.0                140.0
# 214                          NaN                235.0
# 590                         72.0                 85.0

# %%
df.isna().sum()
# Out:
# Make                                0
# Model                               0
# Vehicle Class                       2
# Engine Size(L)                      2
# Cylinders                           2
# Transmission                        4
# Fuel Type                           3
# Fuel Consumption City (L/100 km)    4
# Fuel Consumption Hwy (L/100 km)     2
# Fuel Consumption Comb (L/100 km)    3
# Fuel Consumption Comb (mpg)         3
# CO2 Emissions(g/km)                 0
# dtype: int64

# %%
result_df =df[ df.isnull().sum(axis=1) > 4].index
result_df
# Out:
# Index([21, 23], dtype='int64')

# %%
df.drop(result_df,inplace=True)

# %%
result_df
# Out:
# Index([21, 23], dtype='int64')

# %%
df.isna().sum()
# Out:
# Make                                0
# Model                               0
# Vehicle Class                       1
# Engine Size(L)                      0
# Cylinders                           0
# Transmission                        2
# Fuel Type                           1
# Fuel Consumption City (L/100 km)    2
# Fuel Consumption Hwy (L/100 km)     1
# Fuel Consumption Comb (L/100 km)    2
# Fuel Consumption Comb (mpg)         2
# CO2 Emissions(g/km)                 0
# dtype: int64

# %%
df[df[["Fuel Type"]].isnull().any(axis = 1)]
# Out:
#              Make     Model Vehicle Class  Engine Size(L)  Cylinders  \
# 147  AstON MARTIN  DB11 V12  MINICOMPACT4             4.0       14.0
#
#     Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 147          NaN       NaN                               NaN
#
#      Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 147                             14.4                              12.1
#
#      Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 147                         18.0                363.0

# %%
df[(df["Make"] == "ASTON MARTIN") & (df["Model"] == "DB11 V12") ]
# Out:
#              Make     Model Vehicle Class  Engine Size(L)  Cylinders  \
# 138  ASTON MARTIN  DB11 V12   MINICOMPACT             5.2       12.0
# 144  ASTON MARTIN  DB11 V12   MINICOMPACT             5.2       12.0
#
#     Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 138           A8         Z                              15.5
# 144           A8         Z                              15.5
#
#      Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 138                             11.4                              13.7
# 144                             11.4                              13.7
#
#      Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 138                         21.0                322.0
# 144                         21.0                322.0

# %%
df["Make"].value_counts()
# Out:
# Make
# FORD                                              631
# CHEVROLET                                         594
# BMW                                               529
# MERCEDES-BENZ                                     423
# PORSCHE                                           377
# TOYOTA                                            336
# GMC                                               331
# AUDI                                              295
# NISSAN                                            259
# JEEP                                              253
# DODGE                                             249
# KIA                                               231
# HONDA                                             214
# HYUNDAI                                           210
# MINI                                              205
# VOLKSWAGEN                                        197
# MAZDA                                             181
# LEXUS                                             178
# JAGUAR                                            160
# CADILLAC                                          158
# SUBARU                                            141
# VOLVO                                             124
# INFINITI                                          108
# BUICK                                             103
# RAM                                                98
# LINCOLN                                            96
# MITSUBISHI                                         96
# CHRYSLER                                           88
# LAND ROVER                                         86
# ACURA                                              74
# FIAT                                               73
# MASERATI                                           62
# ROLLS-ROYCE                                        51
# BENTLEY                                            47
# ASTON MARTIN                                       47
# LAMBORGHINI                                        41
# ALFA ROMEO                                         31
# GENESIS                                            25
# SCION                                              22
# SMART                                               7
# BUGATTI                                             3
# SRT                                                 2
# LEXUS UX 250h AWD                                   1
# LAND ROVER Range Rover SVAutobiography Dynamic      1
# LAMBORGHINI Aventador Coupe                         1
# AstON MARTIN                                        1
# Name: count, dtype: int64

# %%
df["Make"].replace("AstON MARTIN", "ASTON MARTIN", inplace=True)

# %%
df["Make"].replace("LEXUS UX 250h AWD", "LEXUS", inplace=True)

# %%
df["Make"].replace("LAND ROVER Range Rover SVAutobiography Dynamic", "LAND ROVER", inplace=True)
df["Make"].replace("LAMBORGHINI Aventador Coupe", "LAMBORGHINI", inplace=True)

# %%
df["Vehicle Class"].replace(" COMPACT", "COMPACT", inplace=True)
df["Vehicle Class"].replace(" MID-SIZE", "MID-SIZE", inplace=True)
df["Vehicle Class"].replace(" TWO-SEATER", "TWO-SEATER", inplace=True)
df["Vehicle Class"].replace(" MINICOMPACT", "MINICOMPACT", inplace=True)
df["Vehicle Class"].replace(" PICKUP TRUCK - STANDARD", "PICKUP TRUCK - STANDARD", inplace=True)
df["Vehicle Class"].replace(" SUBCOMPACT", "SUBCOMPACT", inplace=True)
df["Vehicle Class"].replace(" SUV - SMALL", "SUV - SMALL", inplace=True)
df["Vehicle Class"].replace(" MINICOMPACT4", "MINICOMPACT", inplace=True)
df["Vehicle Class"].replace(" SPECIAL PURPOSE VEHICLE", "SPECIAL PURPOSE VEHICLE", inplace=True)
df["Vehicle Class"].replace(" FULL-SIZE", "FULL-SIZE", inplace=True)
df["Vehicle Class"].replace(" SUV - STANDARD", "SUV - STANDARD", inplace=True)
df["Vehicle Class"].replace("PICKUP TRUCK - SMA", "PICKUP TRUCK - SMALL", inplace=True)
df["Vehicle Class"].replace("MINICOMPACT4", "MINICOMPACT", inplace=True)
df["Vehicle Class"].replace(" MINIVAN", "MINIVAN", inplace=True)
df["Vehicle Class"].replace(" STATION WAGON - MID-SIZE", "STATION WAGON - MID-SIZE", inplace=True)

# %%
df["Vehicle Class"].replace("Aventador Coupe", "TWO-SEATER", inplace=True)

# %%
df["Vehicle Class"].value_counts()
# Out:
# Vehicle Class
# SUV - SMALL                  1220
# MID-SIZE                     1136
# COMPACT                      1026
# SUV - STANDARD                741
# FULL-SIZE                     642
# SUBCOMPACT                    610
# PICKUP TRUCK - STANDARD       539
# TWO-SEATER                    460
# MINICOMPACT                   326
# STATION WAGON - SMALL         252
# PICKUP TRUCK - SMALL          160
# MINIVAN                        81
# SPECIAL PURPOSE VEHICLE        77
# VAN - PASSENGER                66
# STATION WAGON - MID-SIZE       53
# VAN - CARGO                    22
#  COMPACT                        5
#  MID-SIZE                       4
#  TWO-SEATER                     3
#  SUBCOMPACT                     2
#  PICKUP TRUCK - STANDARD        2
#  MINICOMPACT                    2
#  SUV - SMALL                    2
#  SUV - STANDARD                 1
# PICKUP TRUCK - SMA              1
#  FULL-SIZE                      1
# MINICOMPACT4                    1
#  STATION WAGON - MID-SIZE       1
# Aventador Coupe                 1
#  SPECIAL PURPOSE VEHICLE        1
#  MINIVAN                        1
# Name: count, dtype: int64

# %%
df["Model"].value_counts()
# Out:
# Model
# F-150 FFV 4X4                32
# F-150 FFV                    32
# MUSTANG                      27
# FOCUS FFV                    24
# F-150                        20
#                              ..
# AVENTADOR COUPE LP 740        1
# AVENTADOR ROADSTER LP 740     1
# AVENTADOR S COUPE             1
# AVENTADOR S ROADSTER          1
# XC40 T4 AWD                   1
# Name: count, Length: 2074, dtype: int64

# %%
df['Model'] = df['Model'].replace(' 4C', '4C')
df['Model'] = df['Model'].replace(' A4 QUATTRO', 'A4 QUATTRO')
df['Model'] = df['Model'].replace(' A6 QUATTRO', 'A6 QUATTRO')
df['Model'] = df['Model'].replace(' s7', 'S7')
df['Model'] = df['Model'].replace(' F-150 FFV (Payload Pkg)', 'F-150 FFV (Payload Pkg)')
df['Model'] = df['Model'].replace(' 911 Carrera S', '911 Carrera S')
df['Model'] = df['Model'].replace(' Transit Connect Van FFV', 'Transit Connect Van FFV')
df['Model'] = df['Model'].replace(' Phantom', 'Phantom')
df['Model'] = df['Model'].replace(' 1500 eTorque', '1500 eTorque')
df['Model'] = df['Model'].replace(' Crosstrek AWD', 'Crosstrek AWD')
df['Model'] = df['Model'].replace(' 4Runner 4WD', '4Runner 4WD')
df['Model'] = df['Model'].replace(' Sienna', 'Sienna')
df['Model'] = df['Model'].replace(' Eclipse Cross 4WD', 'Eclipse Cross 4WD')
df['Model'] = df['Model'].replace(' Cooper 3 Door', 'Cooper 3 Door')
df['Model'] = df['Model'].replace(' AMG C 43 4MATIC', 'AMG C 43 4MATIC')
df['Model'] = df['Model'].replace(' CX-3', 'CX-3')
df['Model'] = df['Model'].replace(' E 550 4MATIC', 'E 550 CABRIOLET')
df['Model'] = df['Model'].replace(' E 550 CABRIOLET', 'E 550 CABRIOLET')
df['Model'] = df['Model'].replace(' E 63 AMG 4MATIC WAGON', 'E 63 AMG 4MATIC WAGON')
df['Model'] = df['Model'].replace(' GT', 'GT')
df['Model'] = df['Model'].replace(' Ghibli', 'Ghibli')
df['Model'] = df['Model'].replace('s7', 'S7')

# %%
df["Transmission"].replace(" AS8", "AS8", inplace=True)
df["Transmission"].replace(" AS7", "AS7", inplace=True)
df["Transmission"].replace(" AM7", "AM7", inplace=True)
df["Transmission"].replace(" AV8", "AV8", inplace=True)
df["Transmission"].replace(" AS6", "AS6", inplace=True)
df["Transmission"].replace(" AM6", "AM6", inplace=True)
df["Transmission"].replace(" A9", "A9", inplace=True)
df["Transmission"].replace(" AM9", "AM9", inplace=True)
df["Transmission"].replace(" AM8", "AM8", inplace=True)
df["Transmission"].replace(" A8", "A8", inplace=True)
df["Transmission"].replace(" AV6", "AV6", inplace=True)
df["Transmission"].replace(" AS10", "AS10", inplace=True)
df["Transmission"].replace(" AS5", "AS5", inplace=True)

# %%
unique_values = df['Model'].unique()

array1 = []

for value in unique_values:
    # print(value)
    array1.append(value)

sorted_list = sorted(array1)
sorted_list
# Out:
# [' 1500 eTorque',
#  ' 4C',
#  ' 4Runner 4WD',
#  ' 911 Carrera S',
#  ' A4 QUATTRO',
#  ' A6 QUATTRO',
#  ' AMG C 43 4MATIC',
#  ' CX-3',
#  ' Cooper 3 Door',
#  ' Crosstrek AWD',
#  ' E 550 4MATIC',
#  ' E 550 CABRIOLET',
#  ' E 63 AMG 4MATIC WAGON',
#  ' Eclipse Cross 4WD',
#  ' F-150 FFV (Payload Pkg)',
#  ' GT',
#  ' Ghibli',
#  ' Phantom',
#  ' Sienna',
#  ' Transit Connect Van FFV',
#  '124 SPIDER',
#  '124 Spider',
#  '1500',
#  '1500 (MDS)',
#  '1500 4X4',
#  '1500 4X4 (MDS)',
#  '1500 4X4 DIESEL',
#  '1500 4X4 ECODIESEL',
#  '1500 4X4 EcoDiesel',
#  '1500 4X4 FFV',
#  '1500 4X4 eTorque',
#  '1500 Classic',
#  '1500 Classic 4X4',
#  '1500 Classic 4X4 EcoDiesel',
#  '1500 Classic 4X4 FFV',
#  '1500 Classic EcoDiesel',
#  '1500 Classic FFV',
#  '1500 DIESEL',
#  '1500 ECODIESEL',
#  '1500 ECODIESEL HFE',
#  '1500 EcoDiesel',
#  '1500 FFV',
#  '1500 HFE',
#  '1500 HFE eTorque',
#  '1500 eTorque',
#  '200',
#  '200 AWD',
#  '200 AWD FFV',
#  '200 CONVERTIBLE',
#  '200 CONVERTIBLE FFV',
#  '200 FFV',
#  '200 SEDAN',
#  '200 SEDAN FFV',
#  '228i',
#  '228i CABRIOLET',
#  '228i COUPE',
#  '228i xDRIVE',
#  '228i xDRIVE CABRIOLET',
#  '228i xDRIVE COUPE',
#  '230i CABRIOLET',
#  '230i COUPE',
#  '230i Cabriolet',
#  '230i Coupe',
#  '230i xDRIVE CABRIOLET',
#  '230i xDRIVE COUPE',
#  '230i xDrive Cabriolet',
#  '230i xDrive Coupe',
#  '300',
#  '300 (MDS)',
#  '300 AWD',
#  '300 AWD (MDS)',
#  '300 AWD FFV',
#  '300 FFV',
#  '300 SRT (MDS)',
#  '320i',
#  '320i SEDAN',
#  '320i xDRIVE',
#  '320i xDRIVE SEDAN',
#  '328d xDRIVE',
#  '328d xDRIVE SEDAN',
#  '328d xDRIVE TOURING',
#  '328i',
#  '328i SEDAN',
#  '328i xDRIVE',
#  '328i xDRIVE GRAN TURISMO',
#  '328i xDRIVE SEDAN',
#  '328i xDRIVE TOURING',
#  '330i xDRIVE',
#  '330i xDRIVE GRAN TURISMO',
#  '330i xDRIVE TOURING',
#  '330i xDrive',
#  '330i xDrive Gran Turismo',
#  '330i xDrive Sedan',
#  '330i xDrive Touring',
#  '335i',
#  '335i SEDAN',
#  '335i xDRIVE',
#  '335i xDRIVE GRAN TURISMO',
#  '335i xDRIVE SEDAN',
#  '340i',
#  '340i xDRIVE',
#  '340i xDRIVE GRAN TURISMO',
#  '370Z',
#  '370Z COUPE',
#  '370Z ROADSTER',
#  '370Z Roadster',
#  '428i CABRIOLET',
#  '428i COUPE',
#  '428i GRAN COUPE',
#  '428i xDRIVE CABRIOLET',
#  '428i xDRIVE COUPE',
#  '428i xDRIVE GRAN COUPE',
#  '430i Coupe',
#  '430i xDRIVE CABRIOLET',
#  '430i xDRIVE COUPE',
#  '430i xDRIVE GRAN COUPE',
#  '430i xDrive Cabriolet',
#  '430i xDrive Coupe',
#  '430i xDrive Gran Coupe',
#  '435i CABRIOLET',
#  '435i COUPE',
#  '435i GRAN COUPE',
#  '435i xDRIVE CABRIOLET',
#  '435i xDRIVE COUPE',
#  '435i xDRIVE GRAN COUPE',
#  '440i COUPE',
#  '440i Coupe',
#  '440i xDRIVE CABRIOLET',
#  '440i xDRIVE COUPE',
#  '440i xDRIVE GRAN COUPE',
#  '440i xDrive Cabriolet',
#  '440i xDrive Coupe',
#  '440i xDrive Gran Coupe',
#  '4C',
#  '4C COUPE',
#  '4C Coupe',
#  '4C SPIDER',
#  '4C Spider',
#  '4RUNNER (Part-Time 4WD)',
#  '4RUNNER 4WD',
#  '4RUNNER 4WD (Part-Time 4WD)',
#  '4Runner 4WD',
#  '4Runner 4WD (Part-Time 4WD)',
#  '500',
#  '500 ABARTH',
#  '500 ABARTH CABRIO',
#  '500 ABARTH HATCHBACK',
#  '500 CABRIO',
#  '500 CABRIO TURBO',
#  '500 HATCHBACK',
#  '500 HATCHBACK TURBO',
#  '500L',
#  '500L TURBO',
#  '500X',
#  '500X AWD',
#  '528i',
#  '528i SEDAN',
#  '528i xDRIVE',
#  '528i xDRIVE SEDAN',
#  '530i xDRIVE',
#  '530i xDrive',
#  '530i xDrive Sedan',
#  '535d xDRIVE',
#  '535d xDRIVE SEDAN',
#  '535i xDRIVE',
#  '535i xDRIVE GRAN TURISMO',
#  '535i xDRIVE SEDAN',
#  '540i xDRIVE',
#  '540i xDrive',
#  '540i xDrive Sedan',
#  '550i xDRIVE',
#  '550i xDRIVE GRAN TURISMO',
#  '550i xDRIVE SEDAN',
#  '640i xDRIVE CABRIOLET',
#  '640i xDRIVE GRAN COUPE',
#  '640i xDRIVE GRAN TURISMO',
#  '640i xDrive Gran Coupe',
#  '640i xDrive Gran Turismo',
#  '650i xDRIVE CABRIOLET',
#  '650i xDRIVE COUPE',
#  '650i xDRIVE GRAN COUPE',
#  '650i xDrive Gran Coupe',
#  '740Ld xDRIVE SEDAN',
#  '740Li xDRIVE',
#  '740Li xDRIVE SEDAN',
#  '750Li xDRIVE',
#  '750Li xDRIVE SEDAN',
#  '750Li xDrive',
#  '750Li xDrive Sedan',
#  '750i xDRIVE',
#  '750i xDRIVE SEDAN',
#  '750i xDRIVE SWB',
#  '750i xDrive',
#  '750i xDrive Sedan',
#  '760Li',
#  '760Li SEDAN',
#  '86',
#  '911 CARRERA',
#  '911 CARRERA 4',
#  '911 CARRERA 4 CABRIOLET',
#  '911 CARRERA 4 GTS',
#  '911 CARRERA 4 GTS CABRIOLET',
#  '911 CARRERA 4S',
#  '911 CARRERA 4S CABRIOLET',
#  '911 CARRERA CABRIOLET',
#  '911 CARRERA GTS',
#  '911 CARRERA GTS CABRIOLET',
#  '911 CARRERA S',
#  '911 CARRERA S CABRIOLET',
#  '911 Carrera',
#  '911 Carrera 4',
#  '911 Carrera 4 Cabriolet',
#  '911 Carrera 4 GTS',
#  '911 Carrera 4 GTS Cabriolet',
#  '911 Carrera 4S',
#  '911 Carrera 4S Cabriolet',
#  '911 Carrera Cabriolet',
#  '911 Carrera GTS',
#  '911 Carrera GTS Cabriolet',
#  '911 Carrera S',
#  '911 Carrera S Cabriolet',
#  '911 Carrera T',
#  '911 GT2 RS',
#  '911 GT3',
#  '911 GT3 RS',
#  '911 GT3 Touring',
#  '911 GT3RS',
#  '911 Speedster',
#  '911 TARGA 4',
#  '911 TARGA 4 GTS',
#  '911 TARGA 4S',
#  '911 TURBO',
#  '911 TURBO CABRIOLET',
#  '911 TURBO S',
#  '911 TURBO S CABRIOLET',
#  '911 TURBO S EXCLUSIVE',
#  '911 Targa 4',
#  '911 Targa 4 GTS',
#  '911 Targa 4S',
#  '911 Turbo',
#  '911 Turbo Cabriolet',
#  '911 Turbo S',
#  '911 Turbo S Cabriolet',
#  '911 Turbo S Exclusive Cabriolet',
#  'A 220',
#  'A 220 4MATIC',
#  'A 250',
#  'A 250 4MATIC',
#  'A3',
#  'A3 CABRIOLET QUATTRO',
#  'A3 Cabriolet quattro',
#  'A3 QUATTRO',
#  'A3 TDI (modified)',
#  'A3 quattro',
#  'A4',
#  'A4 ALLROAD QUATTRO',
#  'A4 QUATTRO',
#  'A4 ULTRA',
#  'A4 allroad quattro',
#  'A4 quattro',
#  'A5 CABRIOLET QUATTRO',
#  'A5 Cabriolet quattro',
#  'A5 QUATTRO',
#  'A5 SPORTBACK QUATTRO',
#  'A5 Sportback quattro',
#  'A5 quattro',
#  'A6 QUATTRO',
#  'A6 QUATTRO TDI (modified)',
#  'A6 allroad',
#  'A6 quattro',
#  'A7 QUATTRO',
#  'A7 QUATTRO TDI (modified)',
#  'A7 quattro',
#  'A8',
#  'A8 QUATTRO',
#  'A8 QUATTRO TDI (modified)',
#  'A8 TDI (modified)',
#  'A8L',
#  'A8L QUATTRO',
#  'A8L TDI (modified)',
#  'ACADIA',
#  'ACADIA AWD',
#  'ACCENT',
#  'ACCORD',
#  'ACCORD COUPE',
#  'ACCORD HYBRID',
#  'ACCORD SEDAN',
#  'ACCORD SPORT',
#  'ACCORD SPORT/TOURING',
#  'ACTIVEHYBRID 3',
#  'ACTIVEHYBRID 5',
#  'ACTIVEHYBRID 7L',
#  'ALLROAD QUATTRO',
#  'ALPINA B6 xDRIVE GRAN COUPE',
#  'ALPINA B7 xDRIVE',
#  'ALPINA B7 xDRIVE LWB',
#  'ALPINA B7 xDRIVE SWB',
#  'ALTIMA',
#  'ALTIMA 3.5',
#  'ALTIMA SR',
#  'AMG C 43 4MATIC',
#  'AMG C 43 4MATIC CABRIOLET',
#  'AMG C 43 4MATIC COUPE',
#  'AMG C 43 4MATIC Cabriolet',
#  'AMG C 43 4MATIC Coupe',
#  'AMG C 43 4MATIC Wagon',
#  'AMG C 63',
#  'AMG C 63 CABRIOLET',
#  'AMG C 63 COUPE',
#  'AMG C 63 S',
#  'AMG C 63 S CABRIOLET',
#  'AMG C 63 S COUPE',
#  'AMG C 63 S Cabriolet',
#  'AMG C 63 S Coupe',
#  'AMG CLA 45',
#  'AMG CLA 45 4MATIC',
#  'AMG CLS 53 4MATIC+',
#  'AMG CLS 63 S 4MATIC',
#  'AMG E 43 4MATIC',
#  'AMG E 53 4MATIC+',
#  'AMG E 53 4MATIC+ Cabriolet',
#  'AMG E 53 4MATIC+ Coupe',
#  'AMG E 53 4MATIC+ Wagon',
#  'AMG E 63 S 4MATIC',
#  'AMG E 63 S 4MATIC WAGON',
#  'AMG E 63 S 4MATIC+',
#  'AMG E 63 S 4MATIC+ Wagon',
#  'AMG G 63',
#  'AMG G 65',
#  'AMG GL 63 S',
#  'AMG GLA 45',
#  'AMG GLA 45 4MATIC',
#  'AMG GLC 43 4MATIC',
#  'AMG GLC 43 4MATIC COUPE',
#  'AMG GLC 43 4MATIC Coupe',
#  'AMG GLC 63 S 4MATIC+',
#  'AMG GLC 63 S 4MATIC+ Coupe',
#  'AMG GLE 43 4MATIC',
#  'AMG GLE 43 4MATIC COUPE',
#  'AMG GLE 43 4MATIC Coupe',
#  'AMG GLE 63 S 4MATIC',
#  'AMG GLE 63 S 4MATIC COUPE',
#  'AMG GLE 63 S 4MATIC Coupe',
#  'AMG GLE 63 S COUPE 4MATIC',
#  'AMG GLS 63',
#  'AMG GLS 63 4MATIC',
#  'AMG GT 53 4MATIC+ Coupe',
#  'AMG GT 63 4MATIC+ Coupe',
#  'AMG GT 63 S 4MATIC+ Coupe',
#  'AMG GT C COUPE',
#  'AMG GT C Coupe',
#  'AMG GT C ROADSTER',
#  'AMG GT C Roadster',
#  'AMG GT COUPE',
#  'AMG GT R COUPE',
#  'AMG GT R Coupe',
#  'AMG GT ROADSTER',
#  'AMG GT S',
#  'AMG GT S COUPE',
#  'AMG S 63',
#  'AMG S 63 4MATIC',
#  'AMG S 63 4MATIC CABRIOLET',
#  'AMG S 63 4MATIC COUPE',
#  'AMG S 63 4MATIC+',
#  'AMG S 63 4MATIC+ Cabriolet',
#  'AMG S 63 4MATIC+ Coupe',
#  'AMG S 63 CABRIOLET',
#  'AMG S 63 COUPE',
#  'AMG S 65',
#  'AMG S 65 CABRIOLET',
#  'AMG S 65 COUPE',
#  'AMG S 65 Cabriolet',
#  'AMG S 65 Coupe',
#  'AMG SL 63',
#  'AMG SL 65',
#  'AMG SLC 43',
#  'AMG SLK 55',
#  'ARMADA 4WD',
#  'ATLAS',
#  'ATLAS 4MOTION',
#  'ATS',
#  'ATS AWD',
#  'ATS-V',
#  'AVALON',
#  'AVENGER',
#  'AVENGER FFV',
#  'AVENTADOR COUPE',
#  'AVENTADOR COUPE LP 740',
#  'AVENTADOR ROADSTER',
#  'AVENTADOR ROADSTER LP 740',
#  'AVENTADOR S COUPE',
#  'AVENTADOR S ROADSTER',
#  'Acadia',
#  'Acadia AWD',
#  'Accent',
#  'Accord',
#  'Accord Hybrid',
#  'Accord Sport/Touring',
#  'Alpina B6 xDrive Gran Coupe',
#  'Alpina B7 xDrive',
#  'Altima',
#  'Altima AWD',
#  'Altima AWD SR/Platinum',
#  'Altima SR/Platinum',
#  'Armada 4WD',
#  'Arteon 4MOTION',
#  'Ascent AWD',
#  'Atlas',
#  'Atlas 4MOTION',
#  'Atlas Cross Sport 4MOTION',
#  'Avalon',
#  'Aventador Coupe',
#  'Aventador Roadster',
#  'Aviator',
#  'B 250',
#  'B 250 4MATIC',
#  'BEETLE',
#  'BEETLE CONVERTIBLE',
#  'BEETLE DUNE',
#  'BEETLE DUNE CONVERTIBLE',
#  'BEETLE TDI (modified)',
#  'BENTAYGA',
#  'BOXSTER',
#  'BOXSTER GTS',
#  'BOXSTER S',
#  'BOXSTER SPYDER',
#  'BRZ',
#  'BRZ tS',
#  'Beetle',
#  'Beetle Convertible',
#  'Beetle Dune',
#  'Beetle Dune Convertible',
#  'Bentayga',
#  'Blazer',
#  'Blazer AWD',
#  'Boxster',
#  'Boxster GTS',
#  'Boxster S',
#  'C 250',
#  'C 250 COUPE',
#  'C 300 4MATIC',
#  'C 300 4MATIC CABRIOLET',
#  'C 300 4MATIC COUPE',
#  'C 300 4MATIC Cabriolet',
#  'C 300 4MATIC Coupe',
#  'C 300 4MATIC FFV',
#  'C 300 4MATIC WAGON',
#  'C 300 4MATIC Wagon',
#  'C 350',
#  'C 350 4MATIC',
#  'C 350 4MATIC COUPE',
#  'C 350 COUPE',
#  'C 400 4MATIC',
#  'C 450 AMG SPORT 4MATIC',
#  'C 63 AMG',
#  'C 63 AMG COUPE',
#  'C-HR',
#  'C-MAX HYBRID',
#  'CADENZA',
#  'CAMARO',
#  'CAMARO 2LS',
#  'CAMARO SS',
#  'CAMARO Z/28',
#  'CAMARO ZL1',
#  'CAMRY',
#  'CAMRY HYBRID LE',
#  'CAMRY HYBRID XLE/SE',
#  'CAMRY LE/SE',
#  'CAMRY XLE/XSE',
#  'CAMRY XSE',
#  'CANYON',
#  'CANYON 4WD',
#  'CARGO VAN FFV',
#  'CAYENNE',
#  'CAYENNE DIESEL (modified)',
#  'CAYENNE GTS',
#  'CAYENNE PLATINUM',
#  'CAYENNE S',
#  'CAYENNE S HYBRID',
#  'CAYENNE TURBO',
#  'CAYENNE TURBO S',
#  'CAYMAN',
#  'CAYMAN GT4',
#  'CAYMAN GTS',
#  'CAYMAN S',
#  'CC',
#  'CC 4MOTION',
#  'CHALLENGER',
#  'CHALLENGER (MDS)',
#  'CHALLENGER GT',
#  'CHALLENGER GT AWD',
#  'CHALLENGER GT AWD FFV',
#  'CHALLENGER SRT',
#  'CHALLENGER SRT (MDS)',
#  'CHALLENGER SRT DEMON',
#  'CHALLENGER SRT HELLCAT',
#  'CHARGER',
#  'CHARGER (MDS)',
#  'CHARGER AWD',
#  'CHARGER AWD (MDS)',
#  'CHARGER AWD FFV',
#  'CHARGER FFV',
#  'CHARGER SRT (MDS)',
#  'CHARGER SRT 392 HEMI',
#  'CHARGER SRT HELLCAT',
#  'CHEROKEE',
#  'CHEROKEE 4X4',
#  'CHEROKEE 4X4 ACTIVE DRIVE I',
#  'CHEROKEE 4X4 ACTIVE DRIVE I FFV',
#  'CHEROKEE 4X4 ACTIVE DRIVE II',
#  'CHEROKEE 4X4 ACTIVE DRIVE LOCK',
#  'CHEROKEE 4X4 FFV',
#  'CHEROKEE FFV',
#  'CHEROKEE TRAILHAWK 4X4',
#  'CHIRON',
#  'CITY EXPRESS',
#  'CIVIC',
#  'CIVIC COUPE',
#  'CIVIC COUPE Si',
#  'CIVIC HATCHBACK',
#  'CIVIC HATCHBACK SPORT',
#  'CIVIC HYBRID',
#  'CIVIC SEDAN',
#  'CIVIC SEDAN Si',
#  'CIVIC Si',
#  'CIVIC TYPE R',
#  'CL 550 4MATIC',
#  'CL 63 AMG',
#  'CLA 250',
#  'CLA 250 4MATIC',
#  'CLA 250 4MATIC FFV',
#  'CLA 45 AMG',
#  'CLA 45 AMG 4MATIC',
#  'CLS 400 4MATIC',
#  'CLS 450 4MATIC',
#  'CLS 550 4MATIC',
#  'CLS 63 AMG 4MATIC',
#  'CLS 63 AMG S 4MATIC',
#  'COLORADO',
#  'COLORADO 4WD',
#  'COLORADO ZR2 4WD',
#  'COMPASS',
#  'COMPASS 4X4',
#  'COMPASS 4X4 TRAIL RATED',
#  'CONTINENTAL AWD',
#  'CONTINENTAL GT',
#  'CONTINENTAL GT CONVERTIBLE',
#  'CONTINENTAL GT SPEED CONVERTIBLE',
#  'CONTINENTAL GT3-R',
#  'CONTINENTAL GTC',
#  'CONTINENTAL SUPERSPORTS',
#  'COOPER 3 DOOR',
#  'COOPER 5 DOOR',
#  'COOPER CLUBMAN',
#  'COOPER CLUBMAN ALL4',
#  'COOPER CONVERTIBLE',
#  'COOPER COUNTRYMAN',
#  'COOPER COUNTRYMAN ALL4',
#  'COOPER COUPE',
#  'COOPER PACEMAN',
#  'COOPER ROADSTER',
#  'COOPER S 3 DOOR',
#  'COOPER S 5 DOOR',
#  'COOPER S CLUBMAN',
#  'COOPER S CLUBMAN ALL4',
#  'COOPER S CONVERTIBLE',
#  'COOPER S COUNTRYMAN  ALL4',
#  'COOPER S COUNTRYMAN ALL4',
#  'COOPER S COUPE',
#  'COOPER S PACEMAN ALL4',
#  'COOPER S ROADSTER',
#  'COROLLA',
#  'COROLLA LE ECO (1-mode)',
#  'COROLLA LE ECO (2-mode)',
#  'COROLLA MATRIX',
#  'COROLLA iM',
#  'CORVETTE',
#  'CORVETTE Z06',
#  'CR-V',
#  'CR-V AWD',
#  'CR-Z',
#  'CROSSTOUR AWD',
#  'CROSSTREK AWD',
#  'CRUZE',
#  'CRUZE DIESEL',
#  'CRUZE ECO',
#  'CRUZE HATCHBACK',
#  'CRUZE HATCHBACK DIESEL',
#  'CRUZE HATCHBACK PREMIER',
#  'CRUZE LIMITED',
#  'CRUZE LIMITED ECO',
#  'CRUZE PREMIER',
#  'CT 200h',
#  'CT4',
#  'CT4 AWD',
#  'CT4-V',
#  'CT4-V AWD',
#  'CT5',
#  'CT5 AWD',
#  'CT5-V',
#  'CT5-V AWD',
#  'CT6',
#  'CT6 AWD',
#  'CTS',
#  'CTS AWD',
#  'CTS COUPE',
#  'CTS COUPE AWD',
#  'CTS SEDAN',
#  'CTS SEDAN AWD',
#  'CTS SEDAN Vsport',
#  'CTS SPORT WAGON',
#  'CTS SPORT WAGON AWD',
#  'CTS Vsport',
#  'CTS-V',
#  'CTS-V COUPE',
#  'CTS-V SEDAN',
#  'CTS-V SPORT WAGON',
#  'CX-3',
#  'CX-3 (SIL)',
#  'CX-3 4WD',
#  'CX-30',
#  'CX-30 4WD',
#  'CX-30 4WD (Cylinder Deactivation)',
#  'CX-5',
#  'CX-5 ',
#  'CX-5 (Cylinder Deactivation)',
#  'CX-5 (SIL)',
#  'CX-5 4WD',
#  'CX-5 4WD (Cylinder Deactivation)',
#  'CX-5 Diesel 4WD',
#  'CX-5 Turbo 4WD',
#  'CX-9',
#  'CX-9 4WD',
#  'Cadenza',
#  'Camaro',
#  'Camaro SS',
#  'Camaro ZL1',
#  'Camry',
#  'Camry AWD LE/SE',
#  'Camry AWD XLE/XSE',
#  'Camry Hybrid LE',
#  'Camry Hybrid XLE/SE',
#  'Camry LE/SE',
#  'Camry TRD',
#  'Camry XLE/XSE',
#  'Camry XSE',
#  'Canyon',
#  'Canyon 4WD',
#  'Cayenne',
#  'Cayenne S',
#  'Cayenne Turbo',
#  'Cayman',
#  'Cayman GTS',
#  'Cayman S',
#  'Challenger',
#  'Challenger (MDS)',
#  'Challenger AWD',
#  'Challenger GT AWD',
#  'Challenger SRT Hellcat',
#  'Challenger SRT Hellcat Redeye',
#  'Challenger SRT Hellcat Widebody',
#  'Challenger Widebody (MDS)',
#  'Charger',
#  'Charger (MDS)',
#  'Charger AWD',
#  'Charger AWD (MDS)',
#  'Charger AWD FFV',
#  'Charger FFV',
#  'Charger SRT Hellcat',
#  'Charger SRT Hellcat Widebody',
#  'Charger Widebody (MDS)',
#  'Cherokee',
#  'Cherokee 4X4 Active Drive I',
#  'Cherokee 4X4 Active Drive II',
#  'Cherokee 4X4 Active Drive Lock',
#  'Chiron',
#  'Civic Coupe',
#  'Civic Coupe Si',
#  'Civic Hatchback',
#  'Civic Hatchback Sport',
#  'Civic Sedan',
#  'Civic Sedan Si',
#  'Civic Type R',
#  'Colorado',
#  'Colorado 4WD',
#  'Colorado ZR2 4WD',
#  'Compass',
#  'Compass 4X4',
#  'Continental AWD',
#  'Continental GT',
#  'Continental GT Convertible',
#  'Cooper 3 Door',
#  'Cooper 5 Door',
#  'Cooper Clubman ALL4',
#  'Cooper Convertible',
#  'Cooper Countryman ALL4',
#  'Cooper S 3 Door',
#  'Cooper S 5 Door',
#  'Cooper S Clubman ALL4',
#  'Cooper S Convertible',
#  'Cooper S Countryman ALL4',
#  'Corolla',
#  'Corolla Hatchback',
#  'Corolla Hybrid',
#  'Corolla LE Eco',
#  'Corolla XLE',
#  'Corolla XSE',
#  'Corsair AWD',
#  'Corvette',
#  'Corvette Z06',
#  'Corvette ZR1',
#  'Crosstrek AWD',
#  'Cruze',
#  'Cruze Diesel',
#  'Cruze Hatchback',
#  'Cruze Hatchback Diesel',
#  'Cruze Hatchback Premier',
#  'Cruze Premier',
#  'Cullinan',
#  'Cullinan Black Badge',
#  'DART',
#  'DART FFV',
#  'DART GT',
#  'DART TURBO AERO',
#  'DAWN',
#  'DB11 AMR',
#  'DB11 V12',
#  'DB11 V8',
#  'DB9',
#  'DB9 GT',
#  'DBS Superleggera',
#  'DISCOVERY SPORT',
#  'DURANGO AWD',
#  'DURANGO AWD (MDS)',
#  'DURANGO AWD FFV',
#  'DURANGO AWD SRT',
#  'Dawn',
#  'Discovery',
#  'Discovery Sport',
#  'Discovery Sport P250',
#  'Discovery Sport P290',
#  'Discovery TD6 Diesel',
#  'Durango AWD',
#  'Durango AWD SRT',
#  'E 250 BLUETEC 4MATIC',
#  'E 300 4MATIC',
#  'E 350 4MATIC',
#  'E 350 4MATIC COUPE',
#  'E 350 4MATIC WAGON',
#  'E 350 CABRIOLET',
#  'E 350 COUPE',
#  'E 400 4MATIC',
#  'E 400 4MATIC CABRIOLET',
#  'E 400 4MATIC COUPE',
#  'E 400 4MATIC WAGON',
#  'E 400 CABRIOLET',
#  'E 400 COUPE',
#  'E 400 HYBRID',
#  'E 450 4MATIC',
#  'E 450 4MATIC Cabriolet',
#  'E 450 4MATIC Coupe',
#  'E 450 4MATIC Wagon',
#  'E 550 4MATIC',
#  'E 550 CABRIOLET',
#  'E 550 COUPE',
#  'E 63 AMG 4MATIC',
#  'E 63 AMG 4MATIC WAGON',
#  'E 63 AMG S 4MATIC',
#  'E 63 AMG S 4MATIC WAGON',
#  'E-PACE P250',
#  'E-PACE P300',
#  'E150 VAN FFV',
#  'E150 WAGON FFV',
#  'E350 WAGON',
#  'E350 WAGON FFV',
#  'ECLIPSE CROSS',
#  'ECLIPSE CROSS 4WD',
#  'ECOSPORT',
#  'ECOSPORT AWD',
#  'EDGE',
#  'EDGE (Start/Stop)',
#  'EDGE AWD',
#  'EDGE SPORT AWD',
#  'ELANTRA',
#  'ELANTRA COUPE',
#  'ELANTRA GT',
#  'ENCLAVE',
#  'ENCLAVE AWD',
#  'ENCORE',
#  'ENCORE (LE2 Engine)',
#  'ENCORE (LUV Engine)',
#  'ENCORE (SIDI with Stop/Start)',
#  'ENCORE AWD',
#  'ENCORE AWD (LE2 Engine)',
#  'ENCORE AWD (LUV Engine)',
#  'ENCORE AWD (SIDI with Stop/Start)',
#  'ENCORE SPORT TOURING',
#  'ENCORE SPORT TOURING AWD',
#  'ENVISION AWD',
#  'EOS',
#  'EQUINOX',
#  'EQUINOX AWD',
#  'EQUINOX AWD FFV',
#  'EQUINOX FFV',
#  'EQUUS',
#  'ES 300h',
#  'ES 350',
#  'ES 350 F SPORT',
#  'ESCALADE 4WD',
#  'ESCALADE AWD',
#  'ESCALADE ESV 4WD',
#  'ESCALADE ESV AWD',
#  'ESCAPE',
#  'ESCAPE AWD',
#  'ESCAPE FFV',
#  'EXPEDITION 4X4',
#  'EXPEDITION 4X4 FFV',
#  'EXPEDITION EL 4X4',
#  'EXPEDITION MAX 4X4',
#  'EXPLORER',
#  'EXPLORER AWD',
#  'EXPLORER AWD (EcoBoost)',
#  'EXPLORER FFV',
#  'EXPLORER FFV AWD',
#  'EXPRESS 1500 CARGO',
#  'EXPRESS 1500 CARGO AWD',
#  'EXPRESS 1500 CARGO CONV',
#  'EXPRESS 1500 CARGO CONV AWD',
#  'EXPRESS 1500 PASSENGER',
#  'EXPRESS 1500 PASSENGER AWD',
#  'EXPRESS 2500 PASSENGER',
#  'EXPRESS 2500 PASSENGER FFV',
#  'EXPRESS 3500 PASSENGER',
#  'EXPRESS 3500 PASSENGER FFV',
#  'Eclipse Cross 4WD',
#  'EcoSport',
#  'EcoSport AWD',
#  'Edge',
#  'Edge AWD',
#  'Elantra',
#  'Elantra GT',
#  'Enclave',
#  'Enclave AWD',
#  'Encore',
#  'Encore (SIDI with Stop/Start)',
#  'Encore AWD',
#  'Encore AWD (SIDI with Stop/Start)',
#  'Encore GX',
#  'Encore GX AWD',
#  'Envision AWD',
#  'Equinox',
#  'Equinox AWD',
#  'Escalade 4WD',
#  'Escape',
#  'Escape AWD',
#  'Escape FFV',
#  'Escape Hybrid',
#  'Escape Hybrid AWD',
#  'Expedition 4X4',
#  'Expedition MAX 4X4',
#  'Explorer AWD',
#  'Explorer FFV AWD',
#  'Explorer Hybrid AWD',
#  'F-150',
#  'F-150 (LT Tire Pkg)',
#  'F-150 (Payload Pkg)',
#  'F-150 4X4',
#  'F-150 4X4 (LT Tire Pkg)',
#  'F-150 4X4 (Payload Pkg)',
#  'F-150 4X4 Limited',
#  'F-150 4X4 XL/XLT',
#  'F-150 FFV',
#  'F-150 FFV (LT Tire Pkg)',
#  'F-150 FFV (Payload Pkg)',
#  'F-150 FFV 4X4',
#  'F-150 FFV 4X4 (LT Tire Pkg)',
#  'F-150 FFV 4X4 (Payload Pkg)',
#  'F-150 RAPTOR 4WD',
#  'F-150 RAPTOR 4X4',
#  'F-150 Raptor 4X4',
#  'F-PACE 20d',
#  'F-PACE 25t',
#  'F-PACE 30t',
#  'F-PACE 35t',
#  'F-PACE S',
#  'F-PACE SVR',
#  'F-TYPE CONVERTIBLE',
#  'F-TYPE CONVERTIBLE R-DYNAMIC',
#  'F-TYPE CONVERTIBLE R-DYNAMIC AWD',
#  'F-TYPE COUPE',
#  'F-TYPE COUPE R-DYNAMIC',
#  'F-TYPE COUPE R-DYNAMIC AWD',
#  'F-TYPE Convertible',
#  'F-TYPE Convertible R-Dynamic',
#  'F-TYPE Convertible R-Dynamic AWD',
#  'F-TYPE Coupe',
#  'F-TYPE Coupe R-Dynamic',
#  'F-TYPE Coupe R-Dynamic AWD',
#  'F-TYPE P300 Convertible',
#  'F-TYPE P300 Coupe',
#  'F-TYPE PROJECT 7 CONVERTIBLE',
#  'F-TYPE R AWD CONVERTIBLE',
#  'F-TYPE R AWD COUPE',
#  'F-TYPE R AWD Convertible',
#  'F-TYPE R AWD Coupe',
#  'F-TYPE R CONVERTIBLE AWD',
#  'F-TYPE R COUPE AWD',
#  'F-TYPE S CONVERTIBLE',
#  'F-TYPE S CONVERTIBLE AWD',
#  'F-TYPE S COUPE',
#  'F-TYPE S COUPE AWD',
#  'F-TYPE SVR AWD Convertible',
#  'F-TYPE SVR AWD Coupe',
#  'F-TYPE V8 R COUPE',
#  'F-TYPE V8 S CONVERTIBLE',
#  'FIESTA',
#  'FIESTA SFE',
#  'FIESTA ST',
#  'FIT',
#  'FJ CRUISER 4WD',
#  'FLEX',
#  'FLEX AWD',
#  'FLEX AWD (EcoBoost)',
#  'FLEX AWD GTDI',
#  'FLYING SPUR',
#  'FOCUS',
#  'FOCUS (Start/Stop)',
#  'FOCUS FFV',
#  'FOCUS RS AWD',
#  'FOCUS SFE FFV',
#  'FOCUS ST',
#  'FORESTER AWD',
#  'FORTE',
#  'FORTE (GDI)',
#  'FORTE (MPI)',
#  'FORTE 5',
#  'FORTE KOUP',
#  'FORTWO CABRIOLET',
#  'FORTWO COUPE',
#  'FR-S',
#  'FRONTIER',
#  'FRONTIER 4WD',
#  'FUSION',
#  'FUSION (Start/Stop)',
#  'FUSION AWD',
#  'FUSION HYBRID',
#  'Fiesta',
#  'Fiesta ST',
#  'Fit',
#  'Flex',
#  'Flex AWD',
#  'Flex AWD GTDI',
#  'Flying Spur',
#  'Forester AWD',
#  'Forte',
#  'Forte 5',
#  'Frontier',
#  'Frontier 4WD',
#  'Fusion',
#  'Fusion Hybrid',
#  'G 550',
#  'G 63 AMG',
#  'G70',
#  'G70 AWD',
#  'G80 AWD',
#  'G90 AWD',
#  'GALLARDO COUPE',
#  'GENESIS',
#  'GENESIS AWD',
#  'GENESIS COUPE',
#  'GHIBLI',
#  'GHIBLI AWD',
#  'GHIBLI S',
#  'GHIBLI SQ4',
#  'GHOST',
#  'GHOST EWB',
#  'GIULIA',
#  'GIULIA AWD',
#  'GIULIA QUADRIFOGLIO',
#  'GL 350 BLUETEC 4MATIC',
#  'GL 450 4MATIC',
#  'GL 550 4MATIC',
#  'GL 63 AMG',
#  'GLA 250 4MATIC',
#  'GLA 45 AMG 4MATIC',
#  'GLC 300 4MATIC',
#  'GLC 300 4MATIC COUPE',
#  'GLC 300 4MATIC Coupe',
#  'GLE 350d 4MATIC',
#  'GLE 350d 4MATIC COUPE',
#  'GLE 400 4MATIC',
#  'GLE 450 AMG SPORT 4MATIC COUPE',
#  'GLE 550 4MATIC',
#  'GLK 250 BLUETEC 4MATIC',
#  'GLK 350 4MATIC',
#  'GLS 450 4MATIC',
#  'GLS 550 4MATIC',
#  'GOLF',
#  'GOLF ALLTRACK',
#  'GOLF GTI',
#  ...]

# %%
df['Model'].nunique()
# Out:
# 2053

# %%
df.isna().sum()
# Out:
# Make                                0
# Model                               0
# Vehicle Class                       1
# Engine Size(L)                      0
# Cylinders                           0
# Transmission                        2
# Fuel Type                           1
# Fuel Consumption City (L/100 km)    2
# Fuel Consumption Hwy (L/100 km)     1
# Fuel Consumption Comb (L/100 km)    2
# Fuel Consumption Comb (mpg)         2
# CO2 Emissions(g/km)                 0
# dtype: int64

# %%
df[df[["Vehicle Class"]].isnull().any(axis = 1)]
# Out:
#      Make       Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 55  ACURA  TLX SH-AWD           NaN             3.5        6.0          AS9
#
#    Fuel Type  Fuel Consumption City (L/100 km)  \
# 55         Z                              11.4
#
#     Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 55                              7.7                               9.8
#
#     Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 55                         29.0                228.0

# %%
df[(df["Make"] == "ACURA") & (df["Model"] == "TLX SH-AWD") ]
# Out:
#      Make       Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 28  ACURA  TLX SH-AWD       COMPACT             3.5        6.0          AS9
# 36  ACURA  TLX SH-AWD       COMPACT             3.5        6.0          AS9
# 45  ACURA  TLX SH-AWD       COMPACT             3.5        6.0          AS9
# 55  ACURA  TLX SH-AWD           NaN             3.5        6.0          AS9
# 56  ACURA  TLX SH-AWD       COMPACT            -5.6        6.0         AS10
# 68  ACURA  TLX SH-AWD       COMPACT             3.5        6.0          AS9
# 78  ACURA  TLX SH-AWD       COMPACT             3.5        6.0          AS9
#
#    Fuel Type  Fuel Consumption City (L/100 km)  \
# 28         Z                              11.2
# 36         Z                              11.2
# 45         Z                              11.2
# 55         Z                              11.4
# 56         Z                              10.0
# 68         Z                              11.4
# 78         Z                              11.4
#
#     Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 28                              7.5                               9.6
# 36                              7.5                               9.6
# 45                              7.5                               9.6
# 55                              7.7                               9.8
# 56                              1.2                               5.6
# 68                              7.7                               9.8
# 78                              7.7                               9.8
#
#     Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 28                         29.0                221.0
# 36                         29.0                226.0
# 45                         29.0                226.0
# 55                         29.0                228.0
# 56                         30.0                228.0
# 68                         29.0                228.0
# 78                         29.0                228.0

# %%
df.loc[df["Vehicle Class"].isnull(), "Vehicle Class"] = "COMPACT"

# %%
df.isna().sum()
# Out:
# Make                                0
# Model                               0
# Vehicle Class                       0
# Engine Size(L)                      0
# Cylinders                           0
# Transmission                        2
# Fuel Type                           1
# Fuel Consumption City (L/100 km)    2
# Fuel Consumption Hwy (L/100 km)     1
# Fuel Consumption Comb (L/100 km)    2
# Fuel Consumption Comb (mpg)         2
# CO2 Emissions(g/km)                 0
# dtype: int64

# %%
df[df[["Fuel Type"]].isnull().any(axis = 1)]
# Out:
#              Make     Model Vehicle Class  Engine Size(L)  Cylinders  \
# 147  ASTON MARTIN  DB11 V12   MINICOMPACT             4.0       14.0
#
#     Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 147          NaN       NaN                               NaN
#
#      Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 147                             14.4                              12.1
#
#      Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 147                         18.0                363.0

# %%
df[(df["Make"] == "ASTON MARTIN") & (df["Model"] == "DB11 V12") ]
# Out:
#              Make     Model Vehicle Class  Engine Size(L)  Cylinders  \
# 138  ASTON MARTIN  DB11 V12   MINICOMPACT             5.2       12.0
# 144  ASTON MARTIN  DB11 V12   MINICOMPACT             5.2       12.0
# 147  ASTON MARTIN  DB11 V12   MINICOMPACT             4.0       14.0
#
#     Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 138           A8         Z                              15.5
# 144           A8         Z                              15.5
# 147          NaN       NaN                               NaN
#
#      Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 138                             11.4                              13.7
# 144                             11.4                              13.7
# 147                             14.4                              12.1
#
#      Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 138                         21.0                322.0
# 144                         21.0                322.0
# 147                         18.0                363.0

# %%
df.loc[df["Fuel Type"].isnull(), "Transmission"] = "A8"
df.loc[df["Fuel Type"].isnull(), "Fuel Type"] = "Z"

# %%
df[(df["Make"] == "ASTON MARTIN") & (df["Model"] == "DB11 V12") ]
# Out:
#              Make     Model Vehicle Class  Engine Size(L)  Cylinders  \
# 138  ASTON MARTIN  DB11 V12   MINICOMPACT             5.2       12.0
# 144  ASTON MARTIN  DB11 V12   MINICOMPACT             5.2       12.0
# 147  ASTON MARTIN  DB11 V12   MINICOMPACT             4.0       14.0
#
#     Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 138           A8         Z                              15.5
# 144           A8         Z                              15.5
# 147           A8         Z                               NaN
#
#      Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 138                             11.4                              13.7
# 144                             11.4                              13.7
# 147                             14.4                              12.1
#
#      Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 138                         21.0                322.0
# 144                         21.0                322.0
# 147                         18.0                363.0

# %%
df.isna().sum()
# Out:
# Make                                0
# Model                               0
# Vehicle Class                       0
# Engine Size(L)                      0
# Cylinders                           0
# Transmission                        1
# Fuel Type                           0
# Fuel Consumption City (L/100 km)    2
# Fuel Consumption Hwy (L/100 km)     1
# Fuel Consumption Comb (L/100 km)    2
# Fuel Consumption Comb (mpg)         2
# CO2 Emissions(g/km)                 0
# dtype: int64

# %%
df[df[["Transmission"]].isnull().any(axis = 1)]
# Out:
#     Make       Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 590  BMW  335i SEDAN       COMPACT            10.0        2.0          NaN
#
#     Fuel Type  Fuel Consumption City (L/100 km)  \
# 590         Z                              11.5
#
#      Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 590                              8.0                               NaN
#
#      Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 590                         72.0                 85.0

# %%
df[(df["Make"] == "BMW") & (df["Model"] == "335i SEDAN") ]
# Out:
#     Make       Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 588  BMW  335i SEDAN       COMPACT             3.0        6.0          AS8
# 589  BMW  335i SEDAN       COMPACT             3.0        6.0           M6
# 590  BMW  335i SEDAN       COMPACT            10.0        2.0          NaN
#
#     Fuel Type  Fuel Consumption City (L/100 km)  \
# 588         Z                              11.4
# 589         Z                              11.5
# 590         Z                              11.5
#
#      Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 588                              7.4                               9.6
# 589                              7.8                               9.8
# 590                              8.0                               NaN
#
#      Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 588                         29.0                221.0
# 589                         29.0                225.0
# 590                         72.0                 85.0

# %%
df.dropna(subset=["Transmission"], inplace=True)

# %%
df[df[["Transmission"]].isnull().any(axis = 1)]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Vehicle Class, Engine Size(L), Cylinders, Transmission, Fuel Type, Fuel Consumption City (L/100 km), Fuel Consumption Hwy (L/100 km), Fuel Consumption Comb (L/100 km), Fuel Consumption Comb (mpg), CO2 Emissions(g/km)]
# Index: []

# %%
df.isna().sum()
# Out:
# Make                                0
# Model                               0
# Vehicle Class                       0
# Engine Size(L)                      0
# Cylinders                           0
# Transmission                        0
# Fuel Type                           0
# Fuel Consumption City (L/100 km)    2
# Fuel Consumption Hwy (L/100 km)     1
# Fuel Consumption Comb (L/100 km)    1
# Fuel Consumption Comb (mpg)         2
# CO2 Emissions(g/km)                 0
# dtype: int64

# %%
df[df[["Fuel Consumption Comb (L/100 km)"]].isnull().any(axis = 1)]
# Out:
#      Make Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 214  AUDI    S7    SUBCOMPACT             2.0       10.0          AS8
#
#     Fuel Type  Fuel Consumption City (L/100 km)  \
# 214         Z                               NaN
#
#      Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 214                              8.8                               NaN
#
#      Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 214                          NaN                235.0

# %%
audi_fule = df.loc[df["Make"] == "AUDI", "Fuel Consumption Comb (L/100 km)"].mean().round(1)

# %%
df.loc[df["Fuel Consumption Comb (L/100 km)"].isnull(), "Fuel Consumption Comb (L/100 km)"] = audi_fule

# %%
df[df[["Fuel Consumption Comb (L/100 km)"]].isnull().any(axis = 1)]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Vehicle Class, Engine Size(L), Cylinders, Transmission, Fuel Type, Fuel Consumption City (L/100 km), Fuel Consumption Hwy (L/100 km), Fuel Consumption Comb (L/100 km), Fuel Consumption Comb (mpg), CO2 Emissions(g/km)]
# Index: []

# %%
df.isna().sum()
# Out:
# Make                                0
# Model                               0
# Vehicle Class                       0
# Engine Size(L)                      0
# Cylinders                           0
# Transmission                        0
# Fuel Type                           0
# Fuel Consumption City (L/100 km)    2
# Fuel Consumption Hwy (L/100 km)     1
# Fuel Consumption Comb (L/100 km)    0
# Fuel Consumption Comb (mpg)         2
# CO2 Emissions(g/km)                 0
# dtype: int64

# %%
df[df[["Fuel Consumption City (L/100 km)"]].isnull().any(axis = 1)]
# Out:
#              Make     Model Vehicle Class  Engine Size(L)  Cylinders  \
# 147  ASTON MARTIN  DB11 V12   MINICOMPACT             4.0       14.0
# 214          AUDI        S7    SUBCOMPACT             2.0       10.0
#
#     Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 147           A8         Z                               NaN
# 214          AS8         Z                               NaN
#
#      Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 147                             14.4                              12.1
# 214                              8.8                              10.7
#
#      Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 147                         18.0                363.0
# 214                          NaN                235.0

# %%
df.loc[df["Fuel Consumption City (L/100 km)"].isnull(), "Fuel Consumption City (L/100 km)"] = audi_fule

# %%
mask = df["Fuel Consumption City (L/100 km)"].isnull()
df.loc[mask, "Fuel Consumption City (L/100 km)"] = df.loc[mask, "Fuel Consumption Comb (L/100 km)"] * 0.55

# %%
df[df[["Fuel Consumption City (L/100 km)"]].isnull().any(axis = 1)]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Vehicle Class, Engine Size(L), Cylinders, Transmission, Fuel Type, Fuel Consumption City (L/100 km), Fuel Consumption Hwy (L/100 km), Fuel Consumption Comb (L/100 km), Fuel Consumption Comb (mpg), CO2 Emissions(g/km)]
# Index: []

# %%
df.isna().sum()
# Out:
# Make                                0
# Model                               0
# Vehicle Class                       0
# Engine Size(L)                      0
# Cylinders                           0
# Transmission                        0
# Fuel Type                           0
# Fuel Consumption City (L/100 km)    0
# Fuel Consumption Hwy (L/100 km)     1
# Fuel Consumption Comb (L/100 km)    0
# Fuel Consumption Comb (mpg)         2
# CO2 Emissions(g/km)                 0
# dtype: int64

# %%
df[df[["Fuel Consumption Hwy (L/100 km)"]].isnull().any(axis = 1)]
# Out:
#      Make Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 211  AUDI    S7      MID-SIZE             4.0        6.0           A7
#
#     Fuel Type  Fuel Consumption City (L/100 km)  \
# 211         Z                              12.0
#
#      Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 211                              NaN                              10.4
#
#      Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 211                         18.0                240.0

# %%
mask = df["Fuel Consumption Hwy (L/100 km)"].isnull()
mask
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7448    False
# 7449    False
# 7450    False
# 7451    False
# 7452    False
# Name: Fuel Consumption Hwy (L/100 km), Length: 7439, dtype: bool

# %%
df.loc[mask, "Fuel Consumption Hwy (L/100 km)"] = df.loc[mask, "Fuel Consumption Comb (L/100 km)"] * 0.45

# %%
df.isna().sum()
# Out:
# Make                                0
# Model                               0
# Vehicle Class                       0
# Engine Size(L)                      0
# Cylinders                           0
# Transmission                        0
# Fuel Type                           0
# Fuel Consumption City (L/100 km)    0
# Fuel Consumption Hwy (L/100 km)     0
# Fuel Consumption Comb (L/100 km)    0
# Fuel Consumption Comb (mpg)         2
# CO2 Emissions(g/km)                 0
# dtype: int64

# %%
df["Transmission"].value_counts()
# Out:
# Transmission
# AS6      1326
# AS8      1215
# M6        902
# A6        795
# A8        495
# AM7       445
# A9        341
# AS7       320
# AV        295
# M5        194
# AS10      169
# AM6       132
# AV7       118
# AV6       113
# M7         91
# A5         85
# AS9        79
# A4         65
# AM8        62
# A7         55
# AV8        39
# A10        31
# AS5        27
# AV10       11
#  AS8        7
# AM5         4
#  AS7        3
#  AM7        3
# AM9         3
# AS4         2
#  AV8        2
#  AS6        2
#  AM6        1
#  A9         1
#  AM9        1
#  AM8        1
#  A8         1
#  AV6        1
#  AS10       1
#  AS5        1
# Name: count, dtype: int64

# %%
df["Transmission"].value_counts()
# Out:
# Transmission
# AS6     1328
# AS8     1222
# M6       902
# A6       795
# A8       496
# AM7      448
# A9       342
# AS7      323
# AV       295
# M5       194
# AS10     170
# AM6      133
# AV7      118
# AV6      114
# M7        91
# A5        85
# AS9       79
# A4        65
# AM8       63
# A7        55
# AV8       41
# A10       31
# AS5       28
# AV10      11
# AM9        4
# AM5        4
# AS4        2
# Name: count, dtype: int64

# %%
df["Transmission"].nunique()
# Out:
# 27

# %%
df[df[["Fuel Consumption Comb (mpg)"]].isnull().any(axis = 1)]
# Out:
#      Make Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 180  AUDI   A8L     FULL-SIZE             3.0        6.0          AS8
# 214  AUDI    S7    SUBCOMPACT             2.0       10.0          AS8
#
#     Fuel Type  Fuel Consumption City (L/100 km)  \
# 180         Z                              12.6
# 214         Z                              10.7
#
#      Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 180                              7.7                              21.0
# 214                              8.8                              10.7
#
#      Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 180                          NaN                321.0
# 214                          NaN                235.0

# %%
mask = df["Fuel Consumption Comb (mpg)"].isnull()
df.loc[mask, "Fuel Consumption Comb (mpg)"] = 282.481/df.loc[mask, "Fuel Consumption Comb (L/100 km)"].round(1)

# %%
df[df[["Fuel Consumption Comb (mpg)"]].isnull().any(axis = 1)]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Vehicle Class, Engine Size(L), Cylinders, Transmission, Fuel Type, Fuel Consumption City (L/100 km), Fuel Consumption Hwy (L/100 km), Fuel Consumption Comb (L/100 km), Fuel Consumption Comb (mpg), CO2 Emissions(g/km)]
# Index: []

# %%
df.iloc[180]
# Out:
# Make                                       AUDI
# Model                                 Q5 HYBRID
# Vehicle Class                       SUV - SMALL
# Engine Size(L)                              2.0
# Cylinders                                   4.0
# Transmission                                AS8
# Fuel Type                                     Z
# Fuel Consumption City (L/100 km)            9.9
# Fuel Consumption Hwy (L/100 km)             8.3
# Fuel Consumption Comb (L/100 km)            9.2
# Fuel Consumption Comb (mpg)                31.0
# CO2 Emissions(g/km)                       212.0
# Name: 189, dtype: object

# %%
all_duplicated_rows = df.apply(lambda row: row.duplicated(keep=False).all(), axis=1)

df_all_duplicated = df[all_duplicated_rows]

print(df_all_duplicated)
# Out:
# Empty DataFrame
# Columns: [Make, Model, Vehicle Class, Engine Size(L), Cylinders, Transmission, Fuel Type, Fuel Consumption City (L/100 km), Fuel Consumption Hwy (L/100 km), Fuel Consumption Comb (L/100 km), Fuel Consumption Comb (mpg), CO2 Emissions(g/km)]
# Index: []

# %%
df["Transmission"].nunique()
# Out:
# 27

# %%
df[df['Engine Size(L)'] < 0]
# Out:
#      Make       Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 56  ACURA  TLX SH-AWD       COMPACT            -5.6        6.0         AS10
#
#    Fuel Type  Fuel Consumption City (L/100 km)  \
# 56         Z                              10.0
#
#     Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 56                              1.2                               5.6
#
#     Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 56                         30.0                228.0

# %%
A = df[(df["Make"] == "ACURA") & (df["Model"] == "TLX SH-AWD") ]
A["Engine Size(L)"].mode()
# Out:
# 0    3.5
# Name: Engine Size(L), dtype: float64

# %%
df.loc[df['Engine Size(L)'] < 0, "Engine Size(L)"] = A["Engine Size(L)"].mode()

# %%
df.iloc[56]
# Out:
# Make                                     ACURA
# Model                                      NSX
# Vehicle Class                       TWO-SEATER
# Engine Size(L)                             3.5
# Cylinders                                  6.0
# Transmission                               AM9
# Fuel Type                                    Z
# Fuel Consumption City (L/100 km)          11.1
# Fuel Consumption Hwy (L/100 km)           10.8
# Fuel Consumption Comb (L/100 km)          11.0
# Fuel Consumption Comb (mpg)               26.0
# CO2 Emissions(g/km)                      261.0
# Name: 62, dtype: object

# %%
df[df['Cylinders'] < 0]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Vehicle Class, Engine Size(L), Cylinders, Transmission, Fuel Type, Fuel Consumption City (L/100 km), Fuel Consumption Hwy (L/100 km), Fuel Consumption Comb (L/100 km), Fuel Consumption Comb (mpg), CO2 Emissions(g/km)]
# Index: []

# %%
df[df['Cylinders'] % 1 != 0]
# Out:
#            Make   Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 1515  CHEVROLET  MALIBU      MID-SIZE             1.5        3.2           A7
#
#      Fuel Type  Fuel Consumption City (L/100 km)  \
# 1515         X                               8.7
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 1515                              6.3                               7.6
#
#       Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 1515                         37.0                179.0

# %%
df[(df["Make"] == "CHEVROLET") & (df["Model"] == "MALIBU") ]
# Out:
#            Make   Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 1346  CHEVROLET  MALIBU      MID-SIZE             2.0        4.0          AS6
# 1347  CHEVROLET  MALIBU      MID-SIZE             2.5        4.0          AS6
# 1433  CHEVROLET  MALIBU      MID-SIZE             2.0        4.0          AS6
# 1434  CHEVROLET  MALIBU      MID-SIZE             2.5        4.0          AS6
# 1514  CHEVROLET  MALIBU      MID-SIZE             1.5        4.0           A6
# 1515  CHEVROLET  MALIBU      MID-SIZE             1.5        3.2           A7
# 1516  CHEVROLET  MALIBU      MID-SIZE             2.0        4.0          AS8
# 1609  CHEVROLET  MALIBU      MID-SIZE             1.5        4.0           A6
# 1610  CHEVROLET  MALIBU      MID-SIZE             2.0        4.0           A9
# 1694  CHEVROLET  MALIBU      MID-SIZE             1.5        4.0           A6
# 1695  CHEVROLET  MALIBU      MID-SIZE             2.0        4.0           A9
#
#      Fuel Type  Fuel Consumption City (L/100 km)  \
# 1346         Z                              11.5
# 1347         X                               9.3
# 1433         Z                              11.4
# 1434         X                               9.3
# 1514         X                               8.7
# 1515         X                               8.7
# 1516         Z                              10.6
# 1609         X                               8.8
# 1610         Z                              10.7
# 1694         X                               8.8
# 1695         Z                              10.5
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 1346                              7.9                               9.9
# 1347                              6.4                               8.0
# 1433                              7.9                               9.8
# 1434                              6.4                               8.0
# 1514                              6.3                               7.6
# 1515                              6.3                               7.6
# 1516                              7.1                               9.0
# 1609                              6.5                               7.8
# 1610                              7.1                               9.1
# 1694                              6.5                               7.8
# 1695                              7.4                               9.1
#
#       Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 1346                         29.0                228.0
# 1347                         35.0                184.0
# 1433                         29.0                225.0
# 1434                         35.0                184.0
# 1514                         37.0                179.0
# 1515                         37.0                179.0
# 1516                         31.0                211.0
# 1609                         36.0                182.0
# 1610                         31.0                212.0
# 1694                         36.0                181.0
# 1695                         31.0                213.0

# %%
B = df[(df["Make"] == "CHEVROLET") & (df["Model"] == "MALIBU") ]
df.loc[df['Cylinders'] % 1 != 0, "Cylinders"] = B["Cylinders"].mode()

# %%
df.iloc[1516]
# Out:
# Make                                              CHEVROLET
# Model                                     SILVERADO 4WD FFV
# Vehicle Class                       PICKUP TRUCK - STANDARD
# Engine Size(L)                                          5.3
# Cylinders                                               8.0
# Transmission                                             A6
# Fuel Type                                                 E
# Fuel Consumption City (L/100 km)                       20.5
# Fuel Consumption Hwy (L/100 km)                        14.4
# Fuel Consumption Comb (L/100 km)                       17.8
# Fuel Consumption Comb (mpg)                            16.0
# CO2 Emissions(g/km)                                   295.0
# Name: 1530, dtype: object

# %%
df.describe()
# Out:
#        Engine Size(L)    Cylinders  Fuel Consumption City (L/100 km)  \
# count     7438.000000  7438.000000                       7439.000000
# mean         3.193345     5.649906                         12.779271
# std          2.035395     2.295337                         12.417191
# min          0.900000     3.000000                          4.200000
# 25%          2.000000     4.000000                         10.100000
# 50%          3.000000     6.000000                         12.100000
# 75%          3.700000     6.000000                         14.600000
# max         99.000000    88.000000                        999.000000
#
#        Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# count                      7439.000000                       7439.000000
# mean                          9.389944                         11.428324
# std                          17.003696                         19.001582
# min                           1.200000                          4.100000
# 25%                           7.500000                          8.900000
# 50%                           8.700000                         10.600000
# 75%                          10.200000                         12.600000
# max                         999.000000                        999.000000
#
#        Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# count                  7439.000000          7439.000000
# mean                     27.679238           251.074876
# std                      13.863783            60.920912
# min                      11.000000            40.000000
# 25%                      22.000000           208.000000
# 50%                      27.000000           246.000000
# 75%                      32.000000           289.000000
# max                     999.000000          1239.000000

# %%
df[df['Fuel Consumption City (L/100 km)'] < 0]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Vehicle Class, Engine Size(L), Cylinders, Transmission, Fuel Type, Fuel Consumption City (L/100 km), Fuel Consumption Hwy (L/100 km), Fuel Consumption Comb (L/100 km), Fuel Consumption Comb (mpg), CO2 Emissions(g/km)]
# Index: []

# %%
df[df['Fuel Consumption Hwy (L/100 km)'] < 0]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Vehicle Class, Engine Size(L), Cylinders, Transmission, Fuel Type, Fuel Consumption City (L/100 km), Fuel Consumption Hwy (L/100 km), Fuel Consumption Comb (L/100 km), Fuel Consumption Comb (mpg), CO2 Emissions(g/km)]
# Index: []

# %%
df[df['Fuel Consumption Comb (L/100 km)'] < 0]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Vehicle Class, Engine Size(L), Cylinders, Transmission, Fuel Type, Fuel Consumption City (L/100 km), Fuel Consumption Hwy (L/100 km), Fuel Consumption Comb (L/100 km), Fuel Consumption Comb (mpg), CO2 Emissions(g/km)]
# Index: []

# %%
df[df['Fuel Consumption Comb (mpg)'] < 0]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Vehicle Class, Engine Size(L), Cylinders, Transmission, Fuel Type, Fuel Consumption City (L/100 km), Fuel Consumption Hwy (L/100 km), Fuel Consumption Comb (L/100 km), Fuel Consumption Comb (mpg), CO2 Emissions(g/km)]
# Index: []

# %%
df[df['Fuel Consumption Comb (L/100 km)'] < 0]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Vehicle Class, Engine Size(L), Cylinders, Transmission, Fuel Type, Fuel Consumption City (L/100 km), Fuel Consumption Hwy (L/100 km), Fuel Consumption Comb (L/100 km), Fuel Consumption Comb (mpg), CO2 Emissions(g/km)]
# Index: []

# %%
df[df['Fuel Consumption Comb (L/100 km)'] != (df['Fuel Consumption City (L/100 km)'] * 0.55 + df['Fuel Consumption Hwy (L/100 km)'] * 0.45).round(1)]
# Out:
#        Make          Model          Vehicle Class  Engine Size(L)  Cylinders  \
# 16    ACURA            ILX                COMPACT             2.0        4.0
# 18    ACURA     ILX HYBRID                COMPACT             1.5        4.0
# 25    ACURA     RLX HYBRID               MID-SIZE             3.5        6.0
# 26    ACURA            TLX                COMPACT             2.4        4.0
# 27    ACURA            TLX                COMPACT             3.5        6.0
# ...     ...            ...                    ...             ...        ...
# 7423  VOLVO    XC60 T5 AWD            SUV - SMALL             2.0        4.0
# 7433  VOLVO  V60 CC T5 AWD  STATION WAGON - SMALL             2.0        4.0
# 7441  VOLVO         S60 T5                COMPACT             2.0        4.0
# 7444  VOLVO         V60 T5  STATION WAGON - SMALL             2.0        4.0
# 7452  VOLVO    XC90 T6 AWD         SUV - STANDARD             2.0        4.0
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 16            AS5         Z                               9.7
# 18            AV7         Z                               6.0
# 25            AM7         Z                               8.0
# 26            AM8         Z                               9.6
# 27            AS9         Z                              11.2
# ...           ...       ...                               ...
# 7423          AS8         Z                              10.7
# 7433          AS8         Z                              10.8
# 7441          AS8         Z                              10.5
# 7444          AS8         Z                              10.5
# 7452          AS8         Z                              12.2
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 16                                6.7                               8.3
# 18                                6.1                               6.1
# 25                                7.5                               7.7
# 26                                6.6                               8.3
# 27                                6.9                               9.2
# ...                               ...                               ...
# 7423                              8.5                               9.8
# 7433                              7.6                               9.3
# 7441                              7.1                               8.9
# 7444                              7.1                               8.9
# 7452                              8.7                              10.7
#
#       Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 16                           34.0                191.0
# 18                           46.0                140.0
# 25                           37.0                177.0
# 26                           34.0                191.0
# 27                           31.0                212.0
# ...                           ...                  ...
# 7423                         29.0                228.0
# 7433                         30.0                218.0
# 7441                         32.0                208.0
# 7444                         32.0                208.0
# 7452                         26.0                248.0
#
# [1195 rows x 12 columns]

# %%
df['Fuel Consumption Comb (L/100 km)'] = (df['Fuel Consumption City (L/100 km)'] * 0.55 + df['Fuel Consumption Hwy (L/100 km)'] * 0.45).round(1)

# %%
df[df['Fuel Consumption Comb (L/100 km)'] != (df['Fuel Consumption City (L/100 km)'] * 0.55 + df['Fuel Consumption Hwy (L/100 km)'] * 0.45).round(1)]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Vehicle Class, Engine Size(L), Cylinders, Transmission, Fuel Type, Fuel Consumption City (L/100 km), Fuel Consumption Hwy (L/100 km), Fuel Consumption Comb (L/100 km), Fuel Consumption Comb (mpg), CO2 Emissions(g/km)]
# Index: []

# %% [markdown]
# Finding outliers

# %%
df[['Fuel Consumption City (L/100 km)', 'Fuel Consumption Hwy (L/100 km)']].boxplot()

plt.title('Boxplot of Columns A and B')
plt.xlabel('Columns')
plt.ylabel('Values')

plt.show()

# %%
Q1 = df['Fuel Consumption City (L/100 km)'].quantile(0.25)
Q3 = df['Fuel Consumption City (L/100 km)'].quantile(0.75)
IQR = Q3-Q1

Lower_range_limit = Q1 - (1.5* IQR)
Higher_range_limit =Q3 + (1.5* IQR)

# %%
Lower_range_limit
# Out:
# 3.3499999999999996

# %%
Higher_range_limit
# Out:
# 21.35

# %%
df[(df["Fuel Consumption City (L/100 km)"] > Higher_range_limit) | (df["Fuel Consumption City (L/100 km)"] < Lower_range_limit) ]
# Out:
#                Make            Model            Vehicle Class  Engine Size(L)  \
# 142    ASTON MARTIN    V12 VANTAGE S               TWO-SEATER             6.0
# 188            AUDI        Q5 HYBRID              SUV - SMALL             3.0
# 464         BENTLEY  CONTINENTAL GTC               SUBCOMPACT             4.0
# 468         BENTLEY         MULSANNE                 MID-SIZE             6.8
# 476         BENTLEY         MULSANNE                 MID-SIZE             6.8
# ...             ...              ...                      ...             ...
# 4933       MASERATI           Ghibli                 MID-SIZE             3.0
# 5238  MERCEDES-BENZ         AMG G 65           SUV - STANDARD             6.0
# 5299  MERCEDES-BENZ         AMG G 65           SUV - STANDARD             6.0
# 5365  MERCEDES-BENZ         AMG G 65           SUV - STANDARD             6.0
# 6572            RAM     1500 eTorque  PICKUP TRUCK - STANDARD             3.6
#
#       Cylinders Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 142        12.0           M7         Z                              23.2
# 188         4.0          AS8         Z                              39.9
# 464         8.0          AS9         Z                              97.4
# 468         8.0          AS8         Z                              22.3
# 476         8.0          AS8         Z                              22.3
# ...         ...          ...       ...                               ...
# 4933        6.0          AM9         Z                             114.1
# 5238       12.0          AS7         Z                              24.3
# 5299       12.0          AS7         Z                              22.2
# 5365       12.0           A7         Z                              22.2
# 6572        6.0           A8         X                             999.0
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 142                              14.4                              19.2
# 188                               8.3                              25.7
# 464                             210.2                             148.2
# 468                              14.9                              19.0
# 476                              13.3                              18.2
# ...                               ...                               ...
# 4933                              9.8                              67.2
# 5238                             17.9                              21.4
# 5299                             18.0                              20.3
# 5365                             18.0                              20.3
# 6572                              9.4                             553.7
#
#       Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 142                          15.0                450.0
# 188                          31.0                212.0
# 464                          20.0                532.0
# 468                          15.0                437.0
# 476                          16.0                419.0
# ...                           ...                  ...
# 4933                         23.0                286.0
# 5238                         13.0                476.0
# 5299                         14.0                467.0
# 5365                         14.0                473.0
# 6572                         26.0                253.0
#
# [142 rows x 12 columns]

# %%
Q1 = df['Engine Size(L)'].quantile(0.25)
Q3 = df['Engine Size(L)'].quantile(0.75)
IQR = Q3-Q1

Lower_range_limit = Q1 - (1.5* IQR)
Higher_range_limit =Q3 + (1.5* IQR)

# %%
Higher_range_limit
# Out:
# 6.25

# %%
df[(df["Engine Size(L)"] > 10) | (df["Engine Size(L)"] < Lower_range_limit) ]
# Out:
#         Make                 Model   Vehicle Class  Engine Size(L)  Cylinders  \
# 1      ACURA                   ILX         COMPACT            15.0        4.0
# 165     AUDI  A5 CABRIOLET QUATTRO      SUBCOMPACT            12.0        4.0
# 549      BMW  ALPINA B7 xDRIVE LWB       FULL-SIZE            24.4        8.0
# 2162   DODGE            CHALLENGER        MID-SIZE            13.6        6.0
# 5742    MINI         Cooper 3 Door      SUBCOMPACT            88.0        3.0
# 7129  TOYOTA           4Runner 4WD  SUV - STANDARD            99.0        6.0
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 1             AS5         Z                               9.9
# 165           AS7         Z                              11.5
# 549            A8         Z                              15.0
# 2162           A8         X                              12.4
# 5742          AM7         Z                               8.3
# 7129          AS5         X                              14.8
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 1                                 6.7                               8.5
# 165                               8.1                              10.0
# 549                               9.8                              12.7
# 2162                              7.8                              10.3
# 5742                              6.4                               7.4
# 7129                             12.5                              13.8
#
#       Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 1                            33.0                196.0
# 165                          28.0                220.0
# 549                          23.0                297.0
# 2162                         27.0                242.0
# 5742                         38.0                174.0
# 7129                         20.0                321.0

# %%
df.drop(df[(df['Engine Size(L)'] > 10) | (df['Engine Size(L)'] < Lower_range_limit) ].index, inplace=True)

# %%
Lower_range_limit
# Out:
# -0.5500000000000003

# %%
Higher_range_limit
# Out:
# 6.25

# %%
Q1 = df['Cylinders'].quantile(0.25)
Q3 = df['Cylinders'].quantile(0.75)
IQR = Q3-Q1

Lower_range_limit = Q1 - (1.5* IQR)
Higher_range_limit =Q3 + (1.5* IQR)

# %%
df[(df["Cylinders"] > 16) | (df["Cylinders"] < Lower_range_limit) ]
# Out:
#                Make               Model   Vehicle Class  Engine Size(L)  \
# 3179            GMC         TERRAIN AWD     SUV - SMALL             2.0
# 4123           JEEP  GRAND CHEROKEE 4X4  SUV - STANDARD             3.6
# 5535  MERCEDES-BENZ     E 550 CABRIOLET      SUBCOMPACT             4.7
# 6963         TOYOTA              SIENNA         MINIVAN             3.5
#
#       Cylinders Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 3179       54.0           A9         Z                              11.2
# 4123       56.0           A8         X                              12.7
# 5535       88.0          AS7         Z                              13.7
# 6963       56.0          AS6         X                              14.4
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 3179                             9.00                              10.2
# 4123                             9.60                              11.3
# 5535                             9.30                              11.7
# 6963                            10.21                              12.5
#
#       Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 3179                         28.0               1239.0
# 4123                         25.0                265.0
# 5535                         24.0                269.0
# 6963                         23.0                288.0

# %%
Higher_range_limit
# Out:
# 9.0

# %%
df.drop(df[(df['Cylinders'] > 16) | (df['Cylinders'] < Lower_range_limit) ].index, inplace=True)

# %%
Q1 = df['Fuel Consumption City (L/100 km)'].quantile(0.25)
Q3 = df['Fuel Consumption City (L/100 km)'].quantile(0.75)
IQR = Q3-Q1

Lower_range_limit = Q1 - (1.5* IQR)
Higher_range_limit =Q3 + (1.5* IQR)

# %%
df[(df["Fuel Consumption City (L/100 km)"] > Higher_range_limit) | (df["Fuel Consumption City (L/100 km)"] < Lower_range_limit) ]
# Out:
#                Make            Model            Vehicle Class  Engine Size(L)  \
# 142    ASTON MARTIN    V12 VANTAGE S               TWO-SEATER             6.0
# 188            AUDI        Q5 HYBRID              SUV - SMALL             3.0
# 464         BENTLEY  CONTINENTAL GTC               SUBCOMPACT             4.0
# 468         BENTLEY         MULSANNE                 MID-SIZE             6.8
# 476         BENTLEY         MULSANNE                 MID-SIZE             6.8
# ...             ...              ...                      ...             ...
# 4933       MASERATI           Ghibli                 MID-SIZE             3.0
# 5238  MERCEDES-BENZ         AMG G 65           SUV - STANDARD             6.0
# 5299  MERCEDES-BENZ         AMG G 65           SUV - STANDARD             6.0
# 5365  MERCEDES-BENZ         AMG G 65           SUV - STANDARD             6.0
# 6572            RAM     1500 eTorque  PICKUP TRUCK - STANDARD             3.6
#
#       Cylinders Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 142        12.0           M7         Z                              23.2
# 188         4.0          AS8         Z                              39.9
# 464         8.0          AS9         Z                              97.4
# 468         8.0          AS8         Z                              22.3
# 476         8.0          AS8         Z                              22.3
# ...         ...          ...       ...                               ...
# 4933        6.0          AM9         Z                             114.1
# 5238       12.0          AS7         Z                              24.3
# 5299       12.0          AS7         Z                              22.2
# 5365       12.0           A7         Z                              22.2
# 6572        6.0           A8         X                             999.0
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 142                              14.4                              19.2
# 188                               8.3                              25.7
# 464                             210.2                             148.2
# 468                              14.9                              19.0
# 476                              13.3                              18.2
# ...                               ...                               ...
# 4933                              9.8                              67.2
# 5238                             17.9                              21.4
# 5299                             18.0                              20.3
# 5365                             18.0                              20.3
# 6572                              9.4                             553.7
#
#       Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 142                          15.0                450.0
# 188                          31.0                212.0
# 464                          20.0                532.0
# 468                          15.0                437.0
# 476                          16.0                419.0
# ...                           ...                  ...
# 4933                         23.0                286.0
# 5238                         13.0                476.0
# 5299                         14.0                467.0
# 5365                         14.0                473.0
# 6572                         26.0                253.0
#
# [142 rows x 12 columns]

# %%
Higher_range_limit
# Out:
# 21.35

# %%
df.drop(df[(df['Fuel Consumption City (L/100 km)'] > 30) | (df['Fuel Consumption City (L/100 km)'] < Lower_range_limit) ].index, inplace=True)

# %%
Higher_range_limit
# Out:
# 21.35

# %%
Q1 = df['Fuel Consumption Hwy (L/100 km)'].quantile(0.25)
Q3 = df['Fuel Consumption Hwy (L/100 km)'].quantile(0.75)
IQR = Q3-Q1

Lower_range_limit = Q1 - (1.5* IQR)
Higher_range_limit =Q3 + (1.5* IQR)

# %%
df[(df["Fuel Consumption Hwy (L/100 km)"] > Higher_range_limit) | (df["Fuel Consumption Hwy (L/100 km)"] < Lower_range_limit) ]
# Out:
#               Make                 Model            Vehicle Class  \
# 56           ACURA            TLX SH-AWD                  COMPACT
# 142   ASTON MARTIN         V12 VANTAGE S               TWO-SEATER
# 147   ASTON MARTIN              DB11 V12              MINICOMPACT
# 220           AUDI      TT COUPE QUATTRO               SUBCOMPACT
# 468        BENTLEY              MULSANNE                 MID-SIZE
# ...            ...                   ...                      ...
# 6524           RAM          1500 4X4 FFV  PICKUP TRUCK - STANDARD
# 6535           RAM          1500 4X4 FFV  PICKUP TRUCK - STANDARD
# 6554           RAM  1500 Classic 4X4 FFV  PICKUP TRUCK - STANDARD
# 6623   ROLLS-ROYCE               Phantom                FULL-SIZE
# 7131        TOYOTA                Sienna                  MINIVAN
#
#       Engine Size(L)  Cylinders Transmission Fuel Type  \
# 56               NaN        6.0         AS10         Z
# 142              6.0       12.0           M7         Z
# 147              4.0       14.0           A8         Z
# 220              2.0        4.0           A6         Z
# 468              6.8        8.0          AS8         Z
# ...              ...        ...          ...       ...
# 6524             3.6        6.0           A8         E
# 6535             3.6        6.0           A8         E
# 6554             3.6        6.0           A8         E
# 6623             6.7       12.0          AS8         Z
# 7131             3.5        6.0          AS8         X
#
#       Fuel Consumption City (L/100 km)  Fuel Consumption Hwy (L/100 km)  \
# 56                                10.0                              1.2
# 142                               23.2                             14.4
# 147                               10.7                             14.4
# 220                               10.4                             57.6
# 468                               22.3                             14.9
# ...                                ...                              ...
# 6524                              20.7                             14.7
# 6535                              20.7                             14.7
# 6554                              20.7                             14.7
# 6623                              20.0                            999.0
# 7131                              12.6                            999.0
#
#       Fuel Consumption Comb (L/100 km)  Fuel Consumption Comb (mpg)  \
# 56                                 6.0                         30.0
# 142                               19.2                         15.0
# 147                               12.4                         18.0
# 220                               31.6                         31.0
# 468                               19.0                         15.0
# ...                                ...                          ...
# 6524                              18.0                         16.0
# 6535                              18.0                         16.0
# 6554                              18.0                         16.0
# 6623                             460.6                         17.0
# 7131                             456.5                         26.0
#
#       CO2 Emissions(g/km)
# 56                  228.0
# 142                 450.0
# 147                 363.0
# 220                 809.0
# 468                 437.0
# ...                   ...
# 6524                300.0
# 6535                300.0
# 6554                300.0
# 6623                382.0
# 7131                259.0
#
# [213 rows x 12 columns]

# %%
Higher_range_limit
# Out:
# 14.249999999999998

# %%
df.drop(df[(df['Fuel Consumption Hwy (L/100 km)'] > 22) | (df['Fuel Consumption Hwy (L/100 km)'] < Lower_range_limit) ].index, inplace=True)

# %%
df[(df["Fuel Consumption Hwy (L/100 km)"] > 14) | (df["Fuel Consumption Hwy (L/100 km)"] < Lower_range_limit) ]
# Out:
#               Make          Model            Vehicle Class  Engine Size(L)  \
# 142   ASTON MARTIN  V12 VANTAGE S               TWO-SEATER             6.0
# 147   ASTON MARTIN       DB11 V12              MINICOMPACT             4.0
# 468        BENTLEY       MULSANNE                 MID-SIZE             6.8
# 500        BENTLEY       Mulsanne                 MID-SIZE             6.8
# 1037       BUGATTI         CHIRON               TWO-SEATER             8.0
# ...            ...            ...                      ...             ...
# 6883        TOYOTA     TUNDRA 4WD  PICKUP TRUCK - STANDARD             5.7
# 6928        TOYOTA     TUNDRA 4WD  PICKUP TRUCK - STANDARD             5.7
# 7030        TOYOTA     TUNDRA 4WD  PICKUP TRUCK - STANDARD             5.7
# 7075        TOYOTA     Tundra 4WD  PICKUP TRUCK - STANDARD             5.7
# 7126        TOYOTA     Tundra 4WD  PICKUP TRUCK - STANDARD             5.7
#
#       Cylinders Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 142        12.0           M7         Z                              23.2
# 147        14.0           A8         Z                              10.7
# 468         8.0          AS8         Z                              22.3
# 500         8.0          AS8         Z                              24.5
# 1037       16.0          AM7         Z                              26.8
# ...         ...          ...       ...                               ...
# 6883        8.0          AS6         X                              18.5
# 6928        8.0          AS6         X                              18.2
# 7030        8.0          AS6         X                              18.0
# 7075        8.0          AS6         X                              18.0
# 7126        8.0          AS6         X                              18.0
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 142                              14.4                              19.2
# 147                              14.4                              12.4
# 468                              14.9                              19.0
# 500                              14.4                              20.0
# 1037                             16.6                              22.2
# ...                               ...                               ...
# 6883                             14.2                              16.6
# 6928                             14.1                              16.4
# 7030                             14.2                              16.3
# 7075                             14.1                              16.2
# 7126                             14.2                              16.3
#
#       Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 142                          15.0                450.0
# 147                          18.0                363.0
# 468                          15.0                437.0
# 500                          14.0                465.0
# 1037                         13.0                522.0
# ...                           ...                  ...
# 6883                         17.0                382.0
# 6928                         17.0                380.0
# 7030                         17.0                383.0
# 7075                         17.0                382.0
# 7126                         17.0                381.0
#
# [240 rows x 12 columns]

# %%
Q1 = df['CO2 Emissions(g/km)'].quantile(0.25)
Q3 = df['CO2 Emissions(g/km)'].quantile(0.75)
IQR = Q3-Q1

Lower_range_limit = Q1 - (1.5* IQR)
Higher_range_limit =Q3 + (1.5* IQR)

# %%
df[(df["CO2 Emissions(g/km)"] > 550) | (df["CO2 Emissions(g/km)"] < Lower_range_limit) ]
# Out:
#          Make            Model Vehicle Class  Engine Size(L)  Cylinders  \
# 2163    DODGE      CHARGER FFV     FULL-SIZE             3.6        6.0
# 4775    LEXUS  AMG C 43 4MATIC       COMPACT             2.0        4.0
# 6474  PORSCHE    911 Carrera S   MINICOMPACT             3.0        6.0
# 6964   TOYOTA            YARIS       COMPACT             1.5        4.0
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 2163           A5         E                              18.9
# 4775          AV6         X                               5.7
# 6474          AM8         Z                              13.1
# 6964           M5         X                               7.8
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 2163                             12.7                              16.1
# 4775                              6.2                               5.9
# 6474                              9.7                              11.6
# 6964                              5.8                               6.9
#
#       Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 2163                         18.0                868.0
# 4775                         47.0                 40.0
# 6474                         25.0                699.0
# 6964                         41.0                 62.0

# %%
Higher_range_limit
# Out:
# 408.0

# %%
df.drop(df[(df['CO2 Emissions(g/km)'] > 550) | (df['CO2 Emissions(g/km)'] < Lower_range_limit) ].index, inplace=True)
